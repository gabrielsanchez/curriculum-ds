# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Supervised vs. Unsupervised Learning - Practice
#
# Classify problems and create train/test splits.

# %% [markdown]
# ## Exercise 1: Classify These Problems
#
# For each scenario, identify:
# 1. Supervised or Unsupervised?
# 2. If supervised: Regression or Classification? If unsupervised: Clustering or Dimensionality Reduction?
# 3. What are the features (X)?
# 4. What is the label (y), if any?

# %% [markdown]
# ### A. Movie Recommendation
# Netflix wants to suggest movies to users based on their watch history and ratings.
#
# - **Supervised or Unsupervised?** ___________
# - **Task type?** ___________
# - **Features?** ___________
# - **Label/Target?** ___________

# %% [markdown]
# ### B. Customer Segmentation
# An e-commerce company wants to divide its customers into 3-5 groups for targeted marketing, but they don't have predefined groups.
#
# - **Supervised or Unsupervised?** ___________
# - **Task type?** ___________
# - **Features?** ___________
# - **Label/Target?** ___________

# %% [markdown]
# ### C. Handwritten Digit Recognition
# The U.S. Postal Service wants to automatically read handwritten zip codes on mail. They have a dataset of 70,000 labeled images (image → digit 0-9).
#
# - **Supervised or Unsupervised?** ___________
# - **Task type?** ___________
# - **Features?** ___________
# - **Label/Target?** ___________

# %% [markdown]
# ### D. Image Compression
# Reduce 1000-pixel images to 50 features for faster processing while preserving visual information.
#
# - **Supervised or Unsupervised?** ___________
# - **Task type?** ___________
# - **Features?** ___________
# - **Label/Target?** ___________

# %% [markdown]
# ### E. Stock Price Prediction
# A trading firm has historical stock prices and wants to predict tomorrow's closing price.
#
# - **Supervised or Unsupervised?** ___________
# - **Task type?** ___________
# - **Features?** ___________
# - **Label/Target?** ___________

# %% [markdown]
# **Answer:**
