# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Cleaning Data
#
# Prepare data for machine learning by handling missing values, duplicates, and inconsistencies.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## Step 1: Load Raw Data

# %%
# Load a dataset with realistic data quality issues
df = sns.load_dataset('titanic')

print(f"Shape: {df.shape}")
print(f"\nData types:")
print(df.dtypes)
print(f"\nMissing values:")
print(df.isnull().sum())

# %% [markdown]
# ## Step 6: Handle Outliers

# %%
# Check fare distribution
print(f"Fare statistics:")
print(df_clean['fare'].describe())

# Cap extreme values (e.g., fare > 500 is unusual)
df_clean['fare'] = df_clean['fare'].clip(upper=500)

print(f"\nAfter capping:")
print(df_clean['fare'].describe())
