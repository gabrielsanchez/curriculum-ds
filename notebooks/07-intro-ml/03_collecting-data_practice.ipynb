# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Collecting Data - Practice
#
# Load public datasets and evaluate data quality.

# %% [markdown]
# ## Exercise 1: Load Datasets from sklearn

# %%
# TODO: Load the wine dataset using sklearn
# 1. Load the dataset as a DataFrame
# 2. Print the shape
# 3. Print the column names
# 4. Print the first 3 rows
# 5. Print information about data types and missing values

# Your code here

# %% [markdown]
# ## Exercise 3: Data Quality Assessment
#
# Load the breast cancer dataset and evaluate its quality.

# %%
# TODO: Load breast cancer dataset and analyze
# from sklearn.datasets import load_breast_cancer
# 1. Load the dataset
# 2. Check for missing values
# 3. Check class distribution (how many of each label?)
# 4. What are the feature ranges? (min, max)
# 5. Is this dataset suitable for ML? Why or why not?

# Your code here

# %% [markdown]
# ## Exercise 5: Choosing a Dataset for a Project
#
# You're building a house price prediction model. Describe your ideal dataset:
# - How many examples would you want?
# - What features would you need?
# - Where would you get this data?
# - What data quality issues might you encounter?
# - How would you handle them?
