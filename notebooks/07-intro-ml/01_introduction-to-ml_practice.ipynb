# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Introduction to Machine Learning - Practice
#
# Think through ML problems and workflows.

# %% [markdown]
# ## Exercise 1: Rule-Based vs. ML Approach
#
# For each scenario, explain why machine learning is better than writing explicit rules.

# %% [markdown]
# ### Scenario A: Customer Churn Prediction
#
# **Problem:** Predict which customers will cancel their subscription next month.
#
# **Available Data:**
# - Months subscribed
# - Monthly spending
# - Support tickets filed
# - Days since last login
# - Product usage metrics
# - Whether they churned (historical)
#
# **TODO:**
# 1. Why would writing rules be difficult for this problem?
# 2. What patterns might a model discover that a human wouldn't think of?
# 3. How would you collect the training data?

# %% [markdown]
# ### Scenario B: Medical Diagnosis
#
# **Problem:** Diagnose a disease based on patient symptoms and test results.
#
# **TODO:**
# 1. What are the features (inputs) a doctor would consider?
# 2. What is the label (output) the model should predict?
# 3. How much training data would you need?
# 4. What could go wrong if the training data is biased?

# %% [markdown]
# ## Exercise 2: The ML Workflow in Practice
#
# Consider building a recommendation system for an e-commerce company that predicts which products a customer will buy.
#
# **TODO: Walk through each step:**
#
# 1. **Define the Problem**
#    - What exactly are we predicting?
#    - What data do we have access to?
#
# 2. **Collect Data**
#    - What sources could provide this data?
#    - Do we have enough?
#
# 3. **Explore & Clean**
#    - What data quality issues might we encounter?
#    - What would we look for in EDA?
#
# 4. **Engineer Features**
#    - What features should the model see?
#    - What raw data needs transformation?
#
# 5. **Train & Evaluate**
#    - How would we measure success?
#    - What could make a model fail?
#
# 6. **Deploy & Monitor**
#    - How would recommendations be served to users?
#    - What could drift over time?

# %% [markdown]
# ## Exercise 3: Overfitting vs. Generalization
#
# **Scenario:** You build a model that scores 99% on training data but only 70% on test data.
#
# **TODO:**
# 1. What does this pattern indicate?
# 2. Why is predicting on test data more important than training data?
# 3. How might overfitting happen in practice?
# 4. What could you do to fix it?

# %% [markdown]
# ## Exercise 4: Is This a Machine Learning Problem?
#
# For each scenario, decide: Should we use ML or write traditional code?
#
# 1. Calculating federal income tax based on salary → **_____**
#    - Why?
#
# 2. Detecting objects in images → **_____**
#    - Why?
#
# 3. Sending an email reminder at 9am on Tuesdays → **_____**
#    - Why?
#
# 4. Predicting which songs a user will like → **_____**
#    - Why?
#
# 5. Translating English to French → **_____**
#    - Why?
