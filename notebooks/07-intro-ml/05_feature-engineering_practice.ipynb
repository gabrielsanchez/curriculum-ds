# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Feature Engineering - Practice
#
# Transform features to improve model performance.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# ## Exercise 2: Feature Scaling
#
# Compare StandardScaler and MinMaxScaler.

# %%
# TODO: Load iris dataset and scale numeric features
# 1. Separate features and target
# 2. Apply StandardScaler
# 3. Apply MinMaxScaler  
# 4. Compare the results (show mean, std, min, max)
# 5. Which scaler would you prefer for distance-based algorithms?

# Your code here

# %% [markdown]
# ## Exercise 4: Discretization and Binning

# %%
# TODO: Load iris and discretize numeric features
# 1. Load iris dataset
# 2. Create bins for sepal_length (e.g., 'small', 'medium', 'large')
# 3. Create bins for sepal_width
# 4. Show the result
# 5. When would binning be useful?

# Your code here
