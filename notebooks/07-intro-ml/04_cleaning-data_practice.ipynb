# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Cleaning Data - Practice
#
# Clean messy datasets step by step.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Exercise 2: Clean a Dataset
#
# Load 'tips' dataset and clean it.

# %%
# TODO: Load and clean the 'tips' dataset
# 1. Load the dataset
# 2. Check for missing values, duplicates, data types
# 3. Handle any issues you find
# 4. Remove rows where total_bill < 5 (unrealistic)
# 5. Display before and after stats

# Your code here

# %% [markdown]
# ## Exercise 4: Outlier Handling
#
# Detect and handle outliers.

# %%
# TODO: Load 'tips' and examine the 'total_bill' column
# 1. Calculate Q1, Q3, and IQR
# 2. Find outliers (values beyond 1.5*IQR)
# 3. How many outliers are there?
# 4. Remove or cap them (your choice)
# 5. Verify the result

# Your code here
