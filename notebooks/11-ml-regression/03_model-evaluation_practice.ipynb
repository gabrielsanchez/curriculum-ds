# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Model Evaluation for Regression - Practice
#
# Compare models and tune hyperparameters.

# %%
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error, r2_score

# %% [markdown]
# ## Exercise 1: Calculate All Regression Metrics

# %%
# TODO:
# 1. Load diabetes dataset
# 2. Split 80/20, scale features
# 3. Train LinearRegression
# 4. Calculate: MAE, MSE, RMSE, R²
# 5. Interpret each metric

# Your code here

# %% [markdown]
# ## Exercise 2: Cross-Validation
#
# Assess model reliability across different data splits.

# %%
# TODO:
# 1. Perform 5-fold cross-validation with R² scoring
# 2. Print scores for each fold
# 3. Compute mean and std
# 4. Compare single train/test R² vs. CV mean R²
# 5. Is CV estimate higher or lower? What does this mean?

# Your code here

# %% [markdown]
# ## Exercise 3: Compare MAE vs. RMSE

# %%
# TODO:
# 1. Train model and get predictions
# 2. Compute residuals
# 3. Calculate MAE
# 4. Calculate RMSE
# 5. Which is larger, MAE or RMSE?
# 6. Explain why (hint: think about large errors)

# %% [markdown]
# ## Exercise 4: Hyperparameter Search

# %%
# TODO:
# 1. Try Ridge with different alpha values: [0.001, 0.01, 0.1, 1, 10, 100]
# 2. For each alpha:
    # - Train the model
    # - Compute cross-val R²
    # - Compute test R²
# 3. Plot how alpha affects R²
# 4. Which alpha is optimal?

# Your code here

# %% [markdown]
# ## Exercise 5: Model Comparison

# %%
# TODO:
# 1. Train LinearRegression, Ridge, and Lasso
# 2. For each, compute cross-val R² (5 folds)
# 3. Create a comparison table:
    # Model | CV R² | Test R² | MAE
# 4. Which model performs best?
# 5. Is there evidence of overfitting in any model?

# Your code here
