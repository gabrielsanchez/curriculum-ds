# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Introduction to Regression - Practice
#
# Identify regression problems and understand when to use regression vs. classification.

# %% [markdown]
# ## Exercise 1: Classify These Problems
#
# For each scenario, identify whether it's a **regression or classification** problem.

# %% [markdown]
# ### A. Predicting Monthly Sales
# A retail company wants to forecast monthly sales in dollars.
#
# - **Regression or Classification?** ___________
# - **Why?** ___________

# %% [markdown]
# ### B. Credit Card Fraud Detection
# A bank wants to flag transactions as "Fraud" or "Legitimate".
#
# - **Regression or Classification?** ___________
# - **Why?** ___________

# %% [markdown]
# ### C. Student Exam Score Prediction
# Predicting a student's exam score (0-100).
#
# - **Regression or Classification?** ___________
# - **Why?** ___________
# - **Note:** Even though the score is bounded 0-100, it's still regression because output is continuous.

# %% [markdown]
# ### D. Sentiment Analysis
# Classifying reviews as "Positive", "Neutral", or "Negative".
#
# - **Regression or Classification?** ___________
# - **Why?** ___________

# %% [markdown]
# ### E. Drug Dosage Optimization
# Recommending the optimal drug dosage in milligrams for a patient.
#
# - **Regression or Classification?** ___________
# - **Why?** ___________

# %% [markdown]
# ## Exercise 2: Regression Use Cases
#
# For each regression problem, identify:
# 1. **Features** (inputs)
# 2. **Target** (what you're predicting)
# 3. **Why regression is needed** (why not just rules?)

# %% [markdown]
# ### A. House Price Prediction
#
# **Features:** ___________
#
# **Target:** ___________
#
# **Why regression?** ___________

# %% [markdown]
# ### B. Customer Lifetime Value
#
# **Features:** ___________
#
# **Target:** ___________
#
# **Why regression?** ___________

# %% [markdown]
# ## Exercise 3: Understanding Residuals
#
# Your model predicts student test scores. Here are the results:
#
# | Student | True Score | Predicted | Residual |
# |---------|-----------|-----------|----------|
# | A | 85 | 82 | ? |
# | B | 92 | 88 | ? |
# | C | 78 | 80 | ? |
# | D | 95 | 93 | ? |
#
# **TODO:**
# 1. Calculate residuals for each student
# 2. Positive residuals mean the model _________ (underestimated/overestimated)
# 3. Negative residuals mean the model _________ (underestimated/overestimated)
# 4. Which student's prediction was most accurate?
# 5. What's the average error magnitude (ignore sign)?

# %% [markdown]
# ## Exercise 4: Underfitting vs. Overfitting
#
# Match each description to **Underfitting**, **Good Fit**, or **Overfitting**:
#
# - [ ] Underfitting | Model performs well on both training and test data | ___________
# - [ ] Good Fit | Model memorizes noise and fails on new data | ___________
# - [ ] Overfitting | Model is too simple to capture the pattern | ___________

# %% [markdown]
# ## Exercise 5: Continuous vs. Discrete
#
# Some outputs look numeric but might be classification (discrete categories) or regression (continuous).
#
# **Classify each as REGRESSION or CLASSIFICATION:**
#
# 1. Predicting hotel room number → **_____**
# 2. Predicting rainfall amount in mm → **_____**
# 3. Predicting bike-sharing demand (count) → **_____**
# 4. Predicting shirt size (S/M/L/XL) → **_____**
# 5. Predicting electricity consumption in kWh → **_____**
# 6. Predicting number of stars (1-5 rating) → **_____** (Why ambiguous?)
