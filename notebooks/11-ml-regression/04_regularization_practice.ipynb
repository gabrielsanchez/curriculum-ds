# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Regularization - Practice
#
# Apply Ridge, Lasso, and ElasticNet to prevent overfitting.

# %%
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet, RidgeCV, LassoCV
from sklearn.metrics import r2_score

# %% [markdown]
# ## Exercise 1: Ridge vs. Lasso

# %%
# TODO:
# 1. Load diabetes dataset
# 2. Split, scale
# 3. Train Ridge(alpha=1.0) and Lasso(alpha=0.1)
# 4. Print both sets of coefficients
# 5. Count zero coefficients in each
# 6. Which method does feature selection (zeros out coefficients)?

# Your code here

# %% [markdown]
# ## Exercise 2: Alpha Tuning

# %%
# TODO:
# 1. Use RidgeCV to automatically find best alpha
    # alphas = [0.1, 1, 10, 100]
    # cv=5
# 2. Compare to LassoCV
# 3. Which alpha is best for Ridge?
# 4. Which for Lasso?
# 5. How do the test R² scores compare?

# Your code here

# %% [markdown]
# ## Exercise 3: Train/Test Gap

# %%
# TODO:
# 1. Try different alpha values: 0.001, 0.01, 0.1, 1, 10
# 2. For each, compute:
    # - Training R²
    # - Test R²
    # - Gap (train_r2 - test_r2)
# 3. As alpha increases, what happens to the gap?
# 4. Large gap indicates overfitting - which alpha minimizes it?

# Your code here

# %% [markdown]
# ## Exercise 4: ElasticNet with Different l1_ratio

# %%
# TODO:
# 1. Try ElasticNet with alpha=0.1 and different l1_ratio:
    # ratios = [0, 0.25, 0.5, 0.75, 1.0]
# 2. For each:
    # - Train the model
    # - Compute test R²
    # - Count zero coefficients
# 3. l1_ratio=0 is pure Ridge, 1.0 is pure Lasso
# 4. Which ratio gives best test performance?

# Your code here

# %% [markdown]
# ## Exercise 5: Understanding Penalty Effects

# %%
# TODO:
# 1. Create a small dataset with highly correlated features
    # Use diabetes or create synthetic data
# 2. Train LinearRegression, Ridge(alpha=1), Lasso(alpha=0.1)
# 3. Compare coefficient magnitudes
# 4. Why does Ridge shrink all coefficients but Lasso zeros some?
# 5. Explain the mathematical difference (L2 vs L1 penalty)
