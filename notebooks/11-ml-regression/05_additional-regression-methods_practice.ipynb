# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Additional Regression Methods - Practice
#
# Build polynomial and tree-based regression models.

# %%
import numpy as np
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ## Exercise 1: Polynomial Features Impact
#
# Compare different polynomial degrees.

# %%
# TODO:
# 1. Load diabetes dataset
# 2. Split and scale
# 3. Try polynomial degrees 1, 2, 3, 4
# 4. For each:
    # - Create polynomial features
    # - Train LinearRegression
    # - Compute train and test R²
# 5. Plot both train and test R² vs. degree
# 6. What do you notice at high degrees? (overfitting?)

# Your code here

# %% [markdown]
# ## Exercise 2: Decision Tree Depth Tuning

# %%
# TODO:
# 1. Load dataset
# 2. Try DecisionTreeRegressor with max_depth = 1, 2, 3, ..., 15
# 3. For each depth:
    # - Train the model
    # - Compute train and test R²
# 4. Create a plot of R² vs. depth
# 5. Identify optimal depth (best test R²)
# 6. At what depth does overfitting start appearing?

# Your code here

# %% [markdown]
# ## Exercise 3: Feature Importance in Trees

# %%
# TODO:
# 1. Train a DecisionTreeRegressor
# 2. Extract feature_importances_
# 3. Create a ranking of features by importance
# 4. Compare to LinearRegression coefficients
# 5. Do trees and linear models agree on which features matter?

# Your code here

# %% [markdown]
# ## Exercise 4: Min Samples Leaf Parameter

# %%
# TODO:
# 1. Train trees with constant max_depth=10 
# 2. Try different min_samples_leaf: 1, 5, 10, 20, 50
# 3. For each:
    # - Compute train and test R²
    # - Observe the train/test gap
# 4. Increasing min_samples_leaf prevents overfitting
# 5. What is the best min_samples_leaf value?

# Your code here

# %% [markdown]
# ## Exercise 5: Method Comparison on Different Dataset

# %%
# TODO:
# 1. Load a regression dataset (diabetes, california housing, or boston)
# 2. Compare 4 methods:
    # - LinearRegression
    # - PolynomialRegression (degree 2)
    # - DecisionTreeRegressor (tuned depth)
    # - Ridge regression (best alpha)
# 3. Create a comparison table:
    # Model | Train R² | Test R² | Train-Test Gap
# 4. Which model generalizes best?
# 5. Which is most overfit?

# Your code here
