# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Linear Regression - Practice
#
# Train linear regression models and interpret coefficients.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score

# %% [markdown]
# ## Exercise 1: Train on Diabetes Dataset

# %%
# TODO:
# 1. Load diabetes dataset from sklearn
# 2. Split into 80/20 train/test
# 3. Scale features
# 4. Train LinearRegression
# 5. Print MAE and R² on test set

# Your code here

# %% [markdown]
# ## Exercise 2: Interpret Coefficients

# %%
# TODO:
# 1. Get coefficients from your trained model
# 2. Print coefficient name and value for each feature
# 3. Which feature has the largest coefficient (most impact)?
# 4. Which has the smallest (least impact)?
# 5. Do larger coefficients always mean more important features?

# Your code here

# %% [markdown]
# ## Exercise 3: Residual Analysis

# %%
# TODO:
# 1. Calculate residuals on test set
# 2. Compute mean, std, min, max of residuals
# 3. What percentage of residuals are within ±1 std?
# 4. Are there any very large residuals (outliers)?
# 5. Plot distribution of residuals

# Your code here

# %% [markdown]
# ## Exercise 4: Compare Training vs. Test Performance

# %%
# TODO:
# 1. Get model's R² on training set
# 2. Get model's R² on test set
# 3. Compare:
    # - If train R² >> test R², model might be overfitting
    # - If train R² ≈ test R², good generalization
# 4. Do you see signs of overfitting in diabetes model?

# Your code here

# %% [markdown]
# ## Exercise 5: Impact of Scaling

# %%
# TODO:
# 1. Train LinearRegression WITHOUT scaling
# 2. Train LinearRegression WITH scaling
# 3. Compare:
    # - Coefficients
    # - R² scores (should be identical!)
    # - Intercept values
# 4. Why do coefficients differ but R² doesn't?

# Your code here
