# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Correlation Matrix - Practice
#
# Calculate correlations and identify important relationships in data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercise 1: Student Performance Data
#
# Find relationships between study habits and academic performance.

# %%
np.random.seed(42)
n = 80

study_hours = np.random.normal(8, 3, n).clip(0)
class_attendance = 100 - np.random.normal(5, 8, n).clip(0)
sleep_hours = np.random.normal(7, 1.5, n).clip(4, 12)
gpa = (3.0 + study_hours * 0.1 + class_attendance * 0.01 + sleep_hours * 0.05 + np.random.normal(0, 0.3, n)).clip(0, 4)

students = pd.DataFrame({
    "study_hours": study_hours,
    "class_attendance": class_attendance,
    "sleep_hours": sleep_hours,
    "gpa": gpa
})

# %% [markdown]
# ### TODO: Analyze relationships
# 1. Calculate the correlation matrix
# 2. Which factor has the strongest correlation with GPA?
# 3. Create a heatmap visualization
# 4. Interpret the correlations

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: E-commerce Product Data
#
# Identify relationships between product features and sales.

# %%
np.random.seed(42)
n = 100

price = np.random.uniform(10, 200, n)
rating = 2 + price * 0.01 + np.random.normal(0, 0.5, n)
reviews = 50 + rating * 30 + np.random.normal(0, 20, n)
sales = 100 + price * 2 + rating * 50 - reviews * 0.5 + np.random.normal(0, 50, n)

products = pd.DataFrame({
    "price": price.clip(0),
    "rating": rating.clip(1, 5),
    "reviews": reviews.clip(0),
    "monthly_sales": sales.clip(0)
})

# %% [markdown]
# ### TODO: Identify sales drivers
# 1. Calculate correlations between all variables
# 2. Which factors correlate most with monthly_sales?
# 3. Create a heatmap with masked upper triangle
# 4. Are any features multicollinear (highly correlated with each other)?

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Climate Data
#
# Analyze relationships between weather variables.

# %%
np.random.seed(42)
n = 365  # One year of daily data

temp = 20 + 10 * np.sin(np.arange(n) * 2 * np.pi / 365) + np.random.normal(0, 2, n)
humidity = 60 - 10 * np.sin(np.arange(n) * 2 * np.pi / 365) + np.random.normal(0, 5, n)
rainfall = np.abs(np.random.normal(5, 10, n).clip(0))
wind_speed = 15 + 5 * np.sin(np.arange(n) * 2 * np.pi / 180) + np.random.normal(0, 3, n)

climate = pd.DataFrame({
    "temperature_c": temp.clip(-20, 45),
    "humidity_percent": humidity.clip(0, 100),
    "rainfall_mm": rainfall,
    "wind_speed_kmh": wind_speed.clip(0)
})

# %% [markdown]
# ### TODO: Explore weather relationships
# 1. Calculate the full correlation matrix
# 2. Create a heatmap visualization
# 3. Which two variables have the strongest relationship?
# 4. Which variable is most independent of others (has weakest correlations)?

# %%
# Your code here
