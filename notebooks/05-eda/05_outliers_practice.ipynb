# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Outliers - Practice
#
# Detect and handle outliers in various datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## Exercise 1: Customer Purchase Amounts
#
# Identify outliers in transaction data.

# %%
np.random.seed(42)
purchases = pd.DataFrame({
    "transaction_id": range(1, 101),
    "amount": np.concatenate([
        np.random.normal(75, 20, 95).clip(10),
        [500, 450, -50, 1000, 0.01]  # Outliers: high purchases, data errors
    ])
})

# %% [markdown]
# ### TODO: Detect and visualize outliers
# 1. Create a box plot to visualize outliers
# 2. Use IQR method to find outliers (print Q1, Q3, IQR, bounds, count)
# 3. Which values are clearly data errors vs legitimate extreme values?

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Employee Salaries
#
# Identify salary outliers and decide how to handle them.

# %%
np.random.seed(42)
salaries = pd.DataFrame({
    "employee_id": range(1, 51),
    "salary": np.concatenate([
        np.random.normal(60000, 10000, 48).clip(40000),
        [250000, -15000]  # CEO and data error
    ])
})

# %% [markdown]
# ### TODO: Analyze and handle outliers
# 1. Calculate mean and median salary
# 2. Use IQR method to identify outliers
# 3. Compare mean/median before and after removing outliers
# 4. Winsorize the data at 5th and 95th percentiles
# 5. Compare the original, IQR-filtered, and winsorized distributions
