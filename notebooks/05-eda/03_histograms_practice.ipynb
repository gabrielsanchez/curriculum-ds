# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Histograms - Practice
#
# Create histograms from different distributions and identify patterns.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1: Website Traffic
#
# Analyze daily page visits.

# %%
np.random.seed(42)
website = pd.DataFrame({
    "day": range(1, 91),
    "page_visits": np.random.lognormal(7.5, 0.5, 90)  # Right-skewed
})

print(website.head())

# %% [markdown]
# ### TODO: Create and analyze the histogram
# 1. Create a histogram of page_visits with 25 bins
# 2. Add vertical lines for mean (red dashed) and median (orange solid)
# 3. What is the distribution shape? (symmetric, left-skewed, right-skewed?)

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Student Heights
#
# Understand the distribution of student heights.

# %%
np.random.seed(42)
students = pd.DataFrame({
    "student_id": range(1, 201),
    "height_cm": np.random.normal(170, 8, 200)  # Normal distribution
})

# %% [markdown]
# ### TODO: Visualize and interpret
# 1. Create a histogram with 20 bins
# 2. Add mean and median lines
# 3. Create a second histogram with 40 bins - compare detail level
# 4. Is this a symmetric distribution?

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Multiple Distributions
#
# Compare different product categories.

# %%
np.random.seed(42)
products = pd.DataFrame({
    "product_id": range(1, 301),
    "price_budget": np.random.uniform(10, 50, 100),
    "price_mid": np.concatenate([np.random.normal(150, 40, 90), np.random.normal(400, 60, 10)]),
    "price_premium": np.random.lognormal(6, 0.8, 100)
})

# %% [markdown]
# ### TODO: Create subplots for each category
# 1. Create 3 subplots in a row
# 2. Plot histogram for each price category with appropriate bins (15-20)
# 3. Add titles to each subplot
# 4. What does the distribution of each category tell you?

# %%
# Your code here
