# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Summary Statistics - Practice
#
# Calculate statistics on different datasets and interpret what they reveal.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exercise 1: Movie Ratings
#
# Analyze ratings for a set of movies.

# %%
movies = pd.DataFrame({
    "title": ["Action Hero", "Romance Story", "Comedy Night", "Documentary", "Thriller Tale", "SciFi Epic"],
    "imdb_rating": [7.2, 6.8, 7.9, 8.1, 7.5, 8.3],
    "box_office_millions": [150, 85, 120, 25, 95, 200],
    "runtime_minutes": [130, 115, 95, 85, 120, 160]
})

# %% [markdown]
# ### TODO: Calculate statistics
# 1. Calculate mean and median IMDB rating
# 2. Calculate standard deviation of box office earnings
# 3. Find the range of runtime (max - min)
# 4. Calculate Q1 and Q3 for box office

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Employee Salaries
#
# Explore salary data for a company.

# %%
salaries = pd.DataFrame({
    "employee_id": range(1, 11),
    "department": ["Sales", "Engineering", "Sales", "Engineering", "HR", "Sales", "Engineering", "Engineering", "HR", "Sales"],
    "salary": [45000, 85000, 48000, 90000, 55000, 50000, 88000, 92000, 58000, 52000],
    "years_experience": [2, 8, 3, 10, 5, 4, 7, 12, 6, 3]
})

# %% [markdown]
# ### TODO: Compare departments
# 1. Use `.describe()` to get overall salary statistics
# 2. Calculate mean salary for each department
# 3. Which department has the highest median salary?
# 4. Calculate IQR for all salaries

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Test Scores
#
# Analyze test scores to understand the distribution.

# %%
np.random.seed(42)
test_scores = pd.DataFrame({
    "student": range(1, 26),
    "score": np.concatenate([np.random.normal(75, 8, 22), [45, 50, 95]])  # Most normal, a few outliers
})

# %% [markdown]
# ### TODO: Analyze the distribution
# 1. Calculate mean and median
# 2. Is the distribution symmetric? (Compare mean and median)
# 3. Calculate standard deviation
# 4. Find Q1, Q3, and IQR
# 5. Identify potential outliers using the IQR method (values beyond Q1 - 1.5*IQR or Q3 + 1.5*IQR)

# %%
# Your code here
