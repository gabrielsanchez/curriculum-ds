# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Box Plots - Practice
#
# Create and interpret box plots for comparing distributions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercise 1: Restaurant Ratings by Cuisine
#
# Compare ratings across different cuisine types.

# %%
np.random.seed(42)
restaurants = pd.DataFrame({
    "cuisine": ["Italian"] * 40 + ["Asian"] * 40 + ["Mexican"] * 40,
    "rating": np.concatenate([
        np.random.normal(4.0, 0.5, 40).clip(1, 5),
        np.random.normal(3.8, 0.6, 40).clip(1, 5),
        np.random.normal(3.9, 0.55, 40).clip(1, 5)
    ])
})

# %% [markdown]
# ### TODO: Create grouped box plots
# 1. Create a box plot comparing ratings by cuisine using seaborn
# 2. Which cuisine has the highest median rating?
# 3. Which cuisine has the most variability (largest IQR)?

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Test Scores by Subject
#
# Compare student performance across different subjects.

# %%
np.random.seed(42)
scores = pd.DataFrame({
    "subject": ["Math"] * 50 + ["Science"] * 50 + ["English"] * 50 + ["History"] * 50,
    "score": np.concatenate([
        np.random.normal(72, 12, 50).clip(0, 100),
        np.random.normal(75, 10, 50).clip(0, 100),
        np.random.normal(78, 8, 50).clip(0, 100),
        np.random.normal(70, 15, 50).clip(0, 100)
    ])
})

# %% [markdown]
# ### TODO: Analyze the distributions
# 1. Create grouped box plots using seaborn
# 2. Calculate median score for each subject
# 3. Identify which subject has the most outliers
# 4. Which subject shows the most consistent performance?

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Sales by Region and Product
#
# Analyze sales performance across regions.

# %%
np.random.seed(42)
sales = pd.DataFrame({
    "region": ["West"] * 60 + ["East"] * 60 + ["Central"] * 60,
    "sales": np.concatenate([
        np.random.normal(50000, 15000, 56).clip(10000),
        np.concatenate([np.random.normal(50000, 15000, 55), [250000]]),  # 1 outlier
        np.random.normal(45000, 12000, 60).clip(10000)
    ])
})

# %% [markdown]
# ### TODO: Compare regions
# 1. Create grouped box plots with seaborn (use palette="husl")
# 2. Identify which region has outliers
# 3. Compare the median sales across regions
# 4. Add a title: "Sales Distribution by Region"

# %%
# Your code here
