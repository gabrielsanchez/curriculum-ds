# %% [markdown]
# # Introduction to Pandas: Series and DataFrames - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %%
import pandas as pd

# %% [markdown]
# ## Exercise 1: Create and Explore a Revenue Series
#
# Create a Series with quarterly revenue for 2024:
# - Q1: 150000
# - Q2: 175000
# - Q3: 165000
# - Q4: 210000
#
# Then:
# 1. Print the Series
# 2. Access the Q3 revenue using the label
# 3. Filter quarters with revenue greater than 170000
# 4. Calculate the total and average revenue

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Build an Employee DataFrame
#
# Create a DataFrame from a dictionary with employee information:
# - `employee_id`: [101, 102, 103, 104, 105]
# - `name`: ["Alice", "Bob", "Charlie", "Diana", "Eve"]
# - `department`: ["Sales", "IT", "Sales", "HR", "IT"]
# - `salary`: [50000, 65000, 55000, 48000, 67000]
#
# Then:
# 1. Print the entire DataFrame
# 2. Print the first 3 rows
# 3. Print the last row
# 4. Print the `shape` of the DataFrame
# 5. Print the `dtypes`
# 6. Print summary statistics

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Create Sales DataFrame and Explore
#
# Create a DataFrame representing online store sales:
# - `product`: ["Headphones", "Monitor", "Keyboard", "Mouse", "Desk Lamp"]
# - `quantity_sold`: [45, 28, 67, 120, 42]
# - `unit_price`: [79.99, 299.99, 89.99, 24.99, 34.99]
#
# Then:
# 1. Print shape and dtypes
# 2. Print the first 2 rows
# 3. Print `info()` to see column details
# 4. Calculate total revenue per product (quantity × price) and add as a new column (you'll learn this soon)
# 5. Print summary statistics for numeric columns

# %%
# Add your code here
