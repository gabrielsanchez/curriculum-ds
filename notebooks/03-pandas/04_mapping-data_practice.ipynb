# %% [markdown]
# # Mapping Data - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %%
import pandas as pd

# Sample student grades data
df_grades = pd.DataFrame({
    "student":  ["Alice", "Bob", "Charlie", "Diana", "Eve"],
    "math":     [92, 78, 85, 95, 88],
    "english":  [88, 92, 78, 91, 85],
    "science":  [95, 85, 92, 87, 90]
})

print(df_grades)

# %% [markdown]
# ## Exercise 1: Vectorized Operations
#
# Using the grades data:
# 1. Calculate the average score for each student (mean of math, english, science)
# 2. Add a column that converts each average to a percentage out of 100
# 3. Add a column showing the grade difference (math - english)
# 4. Create a column multiplying all scores by 1.05 (5% bonus)
# 5. Display the updated DataFrame

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Map with Functions
#
# Using the grades data (with average calculated):
# 1. Create a function that assigns letter grades:
#    - 90+ = "A"
#    - 80-89 = "B"
#    - 70-79 = "C"
#    - 60-69 = "D"
#    - Below 60 = "F"
# 2. Apply this function to the average scores using `.map()`
# 3. Add the letter grades as a new column
# 4. Display students and their letter grades

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Lambda Functions and Dictionary Mapping
#
# Using the grades data:
# 1. Create a column `student_status` using a lambda function with `.map()`:
#    - "Pass" if math score >= 70
#    - "Fail" if math score < 70
# 2. Add a column formatting lowercase student names using lambda
# 3. Create a dictionary mapping: {"Pass": 1, "Fail": 0}
# 4. Use `.map()` to convert pass/fail to 1/0
# 5. Display the final DataFrame with all new columns

# %%
# Add your code here
