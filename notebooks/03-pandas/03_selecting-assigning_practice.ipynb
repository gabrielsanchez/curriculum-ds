# %% [markdown]
# # Selecting and Assigning Data - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %%
import pandas as pd

# Sample sales data
df_sales = pd.DataFrame({
    "product":  ["Laptop", "Phone", "Tablet", "Monitor", "Keyboard"],
    "quantity": [5, 12, 8, 3, 15],
    "price":    [999, 699, 499, 349, 89],
    "region":   ["North", "South", "East", "West", "North"]
})

print(df_sales)

# %% [markdown]
# ## Exercise 1: Select Columns and Filter Data
#
# Using the sales data:
# 1. Select and print only the "product" and "price" columns
# 2. Filter rows where quantity is greater than 5
# 3. Select products from the "North" region
# 4. Use `loc` to get the first 3 rows' names and prices
# 5. Use `iloc` to get the last 2 rows

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Add Calculated Columns
#
# Using the sales data:
# 1. Add a column `total_revenue` = quantity × price
# 2. Add a column `price_category` with:
#    - "Budget" for price < 200
#    - "Mid-range" for 200 <= price < 700
#    - "Premium" for price >= 700
# 3. Display the updated DataFrame
# 4. Filter and display only "Premium" products

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Complex Filtering and Selection
#
# Using the sales data:
# 1. Create a new DataFrame with only high-value items (price > 300)
# 2. From that new DataFrame, select only product name and region
# 3. Filter for high quantity sales (quantity >= 10) AND from the North region
# 4. Add a profit column assuming 20% margin: profit = total_revenue * 0.20
# 5. Sort by profit (you'll learn this next, but try it!)

# %%
# Add your code here
