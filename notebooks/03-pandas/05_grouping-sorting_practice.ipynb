# %% [markdown]
# # Grouping and Sorting - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %%
import pandas as pd

# Online store purchase data
df_purchases = pd.DataFrame({
    "date":     ["2024-01-01", "2024-01-02", "2024-01-01", "2024-01-03", "2024-01-02", "2024-01-03"],
    "customer": ["Alice", "Bob", "Alice", "Charlie", "Diana", "Bob"],
    "category": ["Electronics", "Electronics", "Books", "Books", "Clothing", "Clothing"],
    "amount":   [150.00, 200.00, 25.50, 18.75, 60.00, 45.00]
})

print(df_purchases)

# %% [markdown]
# ## Exercise 1: Simple Sorting
#
# Using the purchases data:
# 1. Sort by amount (highest first)
# 2. Sort by customer name (alphabetically)
# 3. Sort by date, then by amount (ascending)
# 4. Get the top 3 purchase amounts
# 5. Get the 2 smallest purchases

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Group and Aggregate Data
#
# Using the purchases data:
# 1. Total spending by customer
# 2. Number of purchases per category
# 3. Average purchase amount per category
# 4. Count purchases by customer
# 5. Maximum spending in a single purchase per customer

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Complex Grouping and Sorting
#
# Using the purchases data:
# 1. Group by category and calculate:
#    - Total sales
#    - Count of transactions
#    - Average transaction value
# 2. Sort the result by total sales (descending)
# 3. Find the customer who spent the most (use groupby and nlargest)
# 4. Get the highest and lowest purchase amount per date

# %%
# Add your code here
