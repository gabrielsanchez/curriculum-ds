# %% [markdown]
# # Creating, Reading, and Writing Data - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %%
import pandas as pd

# %% [markdown]
# ## Exercise 1: Create and Save a Movie Database
#
# Create a DataFrame with movie information:
# - `title`: ["The Matrix", "Inception", "Interstellar", "Tenet"]
# - `year`: [1999, 2010, 2014, 2020]
# - `rating`: [8.7, 8.8, 8.6, 7.3]
# - `budget_millions`: [63, 160, 165, 200]
#
# Then:
# 1. Print the DataFrame
# 2. Save it to a CSV file called "movies.csv" (without the index)
# 3. Load it back from the CSV file
# 4. Verify the loaded data matches

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Create from List of Dictionaries
#
# Create a list of student records (dictionaries) with:
# - `student_id`: [1001, 1002, 1003, 1004]
# - `name`: ["Alice", "Bob", "Charlie", "Diana"]
# - `major`: ["Data Science", "Biology", "Engineering", "Data Science"]
# - `gpa`: [3.8, 3.5, 3.9, 3.7]
#
# Then:
# 1. Create a DataFrame from the list
# 2. Set `student_id` as the index
# 3. Print the DataFrame
# 4. Save to CSV (without index)
# 5. Load and display the results

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Multiple File Operations
#
# Create a restaurant inventory DataFrame:
# - `item`: ["Rice", "Chicken", "Tomatoes", "Olive Oil", "Pasta"]
# - `quantity`: [50, 35, 100, 20, 75]
# - `unit_price`: [12.50, 8.99, 0.89, 15.99, 2.50]
#
# Then:
# 1. Print the original DataFrame
# 2. Save to "inventory.csv"
# 3. Load from the file
# 4. Check the shape and dtypes of the loaded data
# 5. Display the first 2 rows

# %%
# Add your code here
