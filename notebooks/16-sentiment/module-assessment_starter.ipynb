# %% [markdown]
# # Save Your Work
#
# Before you begin, save a copy of this notebook to your Google Drive: **File > Save a copy in Drive**.
#
# # Module 16 Assessment — Sentiment Analysis
#
# Build an end-to-end sentiment analysis pipeline on the IMDB movie reviews dataset, comparing a TF-IDF baseline against an LSTM deep learning model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report

VOCAB_SIZE = 10000
MAX_LEN    = 200

(X_train_seq, y_train), (X_test_seq, y_test) = imdb.load_data(num_words=VOCAB_SIZE)

X_train_pad = pad_sequences(X_train_seq, maxlen=MAX_LEN, padding='post', truncating='post')
X_test_pad  = pad_sequences(X_test_seq,  maxlen=MAX_LEN, padding='post', truncating='post')

print(f"Train: {X_train_pad.shape}, Test: {X_test_pad.shape}")
print(f"Positive reviews in train: {y_train.sum()} / {len(y_train)}")

# %% [markdown]
# ## Task 1: Decode Sample Reviews
#
# Decode 3 reviews from integer sequences back to words.
# Print: first 100 decoded words and the sentiment label (Positive/Negative).
# Write 1 sentence per review describing the expressed sentiment.

# %%
word_index = imdb.get_word_index()
reverse_index = {v + 3: k for k, v in word_index.items()}
reverse_index[0] = '<PAD>'
reverse_index[1] = '<START>'
reverse_index[2] = '<UNK>'

def decode_review(sequence):
    return ' '.join([reverse_index.get(i, '?') for i in sequence if i != 0])

# Print 3 decoded reviews (indices 0, 1, 2) with their labels
# Your code here

# %% [markdown]
# *[Your review sentiment descriptions here]*

# %% [markdown]
# ## Task 2: TF-IDF + Logistic Regression Baseline
#
# Convert padded sequences back to space-separated token strings for TF-IDF.
# Train TfidfVectorizer(max_features=5000) + LogisticRegression(max_iter=500).
# Report test accuracy and AUC.

# %%
# Convert sequences to text representation for TF-IDF
X_train_text = [' '.join([str(t) for t in seq if t > 2]) for seq in X_train_seq]
X_test_text  = [' '.join([str(t) for t in seq if t > 2]) for seq in X_test_seq]

# Build and train TF-IDF + LR pipeline
# Your code here

# %% [markdown]
# ## Task 3: LSTM Model
#
# Build a Keras Sequential model:
# - `Embedding(VOCAB_SIZE, 64, input_length=MAX_LEN)`
# - `LSTM(64)`
# - `Dense(1, activation='sigmoid')`
#
# Compile: `binary_crossentropy`, `adam`, `metrics=['accuracy']`
# Train 5 epochs, `validation_split=0.2`
# Report test accuracy and AUC.

# %%
# Your LSTM model here

# %% [markdown]
# ## Task 4: Bidirectional LSTM with Regularization
#
# Extend the model:
# - `Embedding(VOCAB_SIZE, 64, input_length=MAX_LEN)`
# - `Bidirectional(LSTM(64))`
# - `Dropout(0.5)`
# - `Dense(1, activation='sigmoid')`
#
# Use `EarlyStopping(patience=2, restore_best_weights=True)`.
# Report test accuracy, AUC, and which epoch training stopped.

# %%
# Your Bidirectional LSTM model here

# %% [markdown]
# ## Task 5: Comparison Table
#
# | Model | Test Accuracy | AUC |
# |-------|--------------|-----|
# | TF-IDF + Logistic Regression | | |
# | LSTM | | |
# | Bidirectional LSTM + Dropout | | |

# %% [markdown]
# ## Task 6: Error Analysis
#
# Identify 3 misclassified test reviews from the best model.
# Decode each (first 100 words). Write 1 sentence per review explaining the likely linguistic challenge (e.g., sarcasm, negation, domain vocabulary).

# %%
# y_pred_proba = model_bi.predict(X_test_pad).flatten()
# y_pred = (y_pred_proba >= 0.5).astype(int)
# Your error analysis code here

# %% [markdown]
# *[Your error analysis here]*

# %% [markdown]
# ## Task 7: Reflection
#
# Answer in the markdown cell below:
# 1. Why might an LSTM outperform TF-IDF on sentiment analysis?
# 2. What does the Bidirectional wrapper add to the LSTM?
# 3. For production deployment, what additional steps would you take?

# %% [markdown]
# *[Your reflection here]*
