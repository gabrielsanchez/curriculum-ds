# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Introduction to Advanced ML - Practice
#
# Match algorithms to problems and understand trade-offs.

# %%
# Load the breast cancer dataset that we'll use throughout this module
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer = load_breast_cancer()
X = pd.DataFrame(cancer.data, columns=cancer.feature_names)
y = pd.Series(cancer.target)

print(f"Dataset shape: {X.shape}")
print(f"Classes: {cancer.target_names}")
print(f"Class distribution:\n{y.value_counts()}")

# %% [markdown]
# ## Exercise 1: Algorithm Selection
#
# For each scenario, recommend the **best algorithm(s)** and explain why.

# %% [markdown]
# ### Scenario A: Medical Diagnosis System
#
# Requirements:
# - **Data:** 10,000 patient records, 50 medical features
# - **Priority:** Highest accuracy possible (lives depend on it)
# - **Interpretability:** Must explain why the model predicts malignant
# - **Speed:** Inference must be < 100ms per patient
#
# **Your recommendation:** ___________
#
# **Why:** ___________

# %% [markdown]
# ### Scenario B: One-Time Research Project
#
# Requirements:
# - **Data:** 500 examples, 20 features
# - **Priority:** Good accuracy but don't spend weeks tuning
# - **Interpretability:** Would be nice to understand feature importance
# - **Speed:** Not critical (offline analysis)
#
# **Your recommendation:** ___________
#
# **Why:** ___________

# %% [markdown]
# ### Scenario C: Real-Time Mobile App
#
# Requirements:
# - **Data:** 1 million training examples, 100 features
# - **Priority:** Fast inference (< 10ms per prediction)
# - **Interpretability:** Not critical (black box okay)
# - **Training:** Can happen offline, takes hours
#
# **Your recommendation:** ___________
#
# **Why:** ___________

# %% [markdown]
# ### Scenario D: Finding Needle in Haystack
#
# Requirements:
# - **Data:** 5 million transactions, 200 features
# - **Priority:** Capture all true positives (detect fraud), false positives okay
# - **Interpretability:** Need to understand patterns
# - **Speed:** Can process offline
#
# **Your recommendation:** ___________
#
# **Why:** ___________

# %% [markdown]
# ## Exercise 2: Strengths and Weaknesses
#
# Fill in the table:

# %% [markdown]
# | Algorithm | Key Strength | Key Weakness |
# |-----------|--------------|---------------|
# | kNN | _________ | _________ |
# | SVM | _________ | _________ |
# | Random Forest | _________ | _________ |
# | Gradient Boosting | _________ | _________ |
# | Neural Networks | _________ | _________ |

# %% [markdown]
# ## Exercise 3: Trade-offs
#
# For each pair, which algorithm wins on each criterion?
#
# **A. Random Forest vs. Gradient Boosting:**
# - Easiest to tune: _________
# - Likely higher accuracy: _________
# - Faster training: _________
# - Less prone to overfitting: _________
#
# **B. SVM vs. Neural Networks:**
# - Works better with small datasets: _________
# - Better for images: _________
# - Faster training: _________
# - More interpretable: _________
#
# **C. kNN vs. Logistic Regression:**
# - Faster training: _________
# - Faster prediction: _________
# - Better on non-linear data: _________
# - Better on high-dimensional data: _________

# %% [markdown]
# ## Exercise 4: No Free Lunch
#
# Give an example of a scenario where each algorithm would be best:

# %% [markdown]
# 1. **kNN is best:** ___________
# 2. **SVM is best:** ___________
# 3. **Random Forest is best:** ___________
# 4. **Gradient Boosting is best:** ___________
# 5. **Neural Networks are best:** ___________

# %% [markdown]
# ## Exercise 5: Dataset Characteristics
#
# Analyze the breast cancer dataset and propose which algorithm might work best here.

# %%
# TODO:
# 1. Print number of samples, features
# 2. Check if data is high-dimensional (many features relative to samples?)
# 3. Analyze class balance
# 4. Based on these characteristics, which algorithms would you try first?

# Your code here
