# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Neural Networks - Practice
#
# Design network architecture and tune regularization.

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

# %% [markdown]
# ## Exercise 1: Architecture Search

# %%
# TODO:
# 1. Load cancer data, split, scale
# 2. Try different hidden_layer_sizes:
    # (50,), (100,), (200,)
    # (100, 50), (100, 100)
    # (100, 50, 25)
# 3. For each architecture:
    # - Train with max_iter=1000
    # - Get train, test accuracy
# 4. Which performs best?
# 5. Which is simplest (fewer parameters)?

# Your code here

# %% [markdown]
# ## Exercise 2: Regularization Strength

# %%
# TODO:
# 1. Fix architecture: (100, 50)
# 2. Try alpha (L2 regularization): [0.0, 0.00001, 0.0001, 0.001, 0.01, 0.1]
# 3. For each alpha:
    # - Get train and test accuracy
    # - Compute overfitting gap
# 4. Which alpha minimizes overfitting?
# 5. Create visualization of alpha vs. accuracy

# Your code here

# %% [markdown]
# ## Exercise 3: Activation Functions

# %%
# TODO:
# 1. Compare activations: 'identity', 'logistic', 'tanh', 'relu'
# 2. Use fixed architecture (100,) and alpha=0.001
# 3. For each activation:
    # - Train and get test accuracy
    # - Report AUC
# 4. Which activation is best?
# 5. Why is ReLU popular?

# Your code here

# %% [markdown]
# ## Exercise 4: Solver and Learning Rate

# %%
# TODO:
# 1. Try different solvers: 'lbfgs', 'sgd', 'adam'
# 2. For each solver:
    # - Train network
    # - Get test accuracy
    # - (Note: only 'sgd' and 'adam' have learning_rate parameter)
# 3. Which solver is fastest?
# 4. Which gives best accuracy?

# Your code here

# %% [markdown]
# ## Exercise 5: Final Algorithm Comparison

# %%
# TODO:
# 1. Train all algorithms covered in this module:
    # - kNN (best k)
    # - SVM (best C, gamma)
    # - Random Forest (best n_trees, depth)
    # - Gradient Boosting (best learning_rate, n_trees)
    # - Neural Network (best architecture, alpha)
# 2. Create comprehensive comparison table:
    # Algorithm | Accuracy | AUC | Complexity (params) | Speed
# 3. Which algorithm would you recommend?
# 4. What are trade-offs?

# Your code here
