# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Gradient Boosting - Practice
#
# Tune boosting parameters for optimal performance.

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

# %% [markdown]
# ## Exercise 1: Learning Rate Impact

# %%
# TODO:
# 1. Load cancer data, split
# 2. Try learning_rate: [0.001, 0.01, 0.05, 0.1, 0.2, 0.5]
# 3. Fix n_estimators=100
# 4. For each learning rate:
    # - Get train and test accuracy
    # - Compute overfitting gap
# 5. Which learning rate is best?
# 6. Is there a relationship with overfitting?

# Your code here

# %% [markdown]
# ## Exercise 2: Early Stopping Pattern

# %%
# TODO:
# 1. For learning_rates [0.01, 0.1, 0.5]:
# 2. Try n_estimators from 1 to 500
# 3. Track train and test accuracy
# 4. For each learning rate, find where test accuracy peaks
# 5. Create 3 plots showing learning curves
# 6. Which learning rate peaks earliest? Latest?

# Your code here

# %% [markdown]
# ## Exercise 3: max_depth in boosting

# %%
# TODO:
# 1. Fix learning_rate=0.1, n_estimators=100
# 2. Try max_depth: 1, 2, 3, 5, 10
    # (gradient boosting uses "weak learners" — shallow trees)
# 3. For each depth:
    # - Get test accuracy
# 4. Which depth works best?
# 5. Why are shallow trees preferred in boosting?

# Your code here

# %% [markdown]
# ## Exercise 4: GridSearchCV

# %%
# TODO:
# 1. Use GridSearchCV to find best combination:
    # n_estimators: [50, 100, 200]
    # learning_rate: [0.01, 0.05, 0.1]
    # max_depth: [2, 3, 5]
# 2. Use 5-fold cross-validation
# 3. Report best parameters
# 4. Get best CV score
# 5. Evaluate on test set

# Your code here

# %% [markdown]
# ## Exercise 5: Boosting vs. Bagging

# %%
# TODO:
# 1. Train optimized:
    # - RandomForestClassifier (from Exercise 4 of random forests)
    # - GradientBoostingClassifier (best from GridSearch above)
# 2. Create comparison table:
    # Model | Train Acc | Test Acc | Overfitting Gap | AUC
# 3. Which is more accurate?
# 4. Which generalizes better (smaller gap)?
# 5. Would you choose bagging or boosting for this problem?

# Your code here
