# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Support Vector Machines - Practice
#
# Tune SVM hyperparameters C and gamma.

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, roc_auc_score

# %% [markdown]
# ## Exercise 1: C Parameter Tuning

# %%
# TODO:
# 1. Load cancer data, split, scale
# 2. Try C values: [0.001, 0.01, 0.1, 1, 10, 100, 1000]
# 3. For each C with kernel='linear':
    # - Train model
    # - Compute train and test accuracy
    # - Count support vectors
# 4. Plot: C vs accuracy and C vs number of support vectors
# 5. Why do large C values create more support vectors?

# Your code here

# %% [markdown]
# ## Exercise 2: Kernel Comparison

# %%
# TODO:
# 1. Compare these kernels: 'linear', 'rbf', 'poly'
# 2. Use best C from Exercise 1
# 3. For each kernel:
    # - Train and evaluate
    # - Report accuracy, AUC, support vectors
# 4. Which kernel performs best?
# 5. Which is fastest to train?

# Your code here

# %% [markdown]
# ## Exercise 3: Gamma Tuning (RBF)

# %%
# TODO:
# 1. Focus on RBF kernel (non-linear)
# 2. Try gamma values: [0.0001, 0.001, 0.01, 0.1, 1, 10]
# 3. Fix C=1.0
# 4. For each gamma:
    # - Train/test accuracy
    # - Overfitting gap (train - test)
# 5. Which gamma minimizes overfitting?
# 6. Create a visualization

# Your code here

# %% [markdown]
# ## Exercise 4: GridSearchCV

# %%
# TODO:
# 1. Use GridSearchCV to find best C and gamma
    # param_grid = {'C': [...], 'gamma': [...]}
    # Use kernel='rbf'
# 2. Use 5-fold cross-validation
# 3. Report best parameters and best CV score
# 4. Evaluate on test set
# 5. How much better than default C=1, gamma='scale'?

# Your code here

# %% [markdown]
# ## Exercise 5: Model Comparison

# %%
# TODO:
# 1. Train these models:
    # - Logistic Regression
    # - SVM (linear)
    # - SVM (RBF)
    # - Random Forest
# 2. Create comparison table:
    # Model | Accuracy | AUC | Training Time | Support Vectors (if applicable)
# 3. Which model is best overall?
# 4. Which is best for deployment (fastest inference)?

# Your code here
