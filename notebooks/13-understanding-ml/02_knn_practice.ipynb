# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # k-Nearest Neighbors - Practice
#
# Tune kNN and explore distance metrics.

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

# %% [markdown]
# ## Exercise 1: k Selection

# %%
# TODO:
# 1. Load breast cancer dataset
# 2. Split 80/20 and scale
# 3. Try k = 1, 3, 5, 10, 20, 50, 100
# 4. For each k, compute:
    # - Training accuracy
    # - Test accuracy
    # - Gap (train - test)
# 5. What k minimizes overfitting?
# 6. Create a plot

# Your code here

# %% [markdown]
# ## Exercise 2: Distance Metrics Comparison

# %%
# TODO:
# 1. Compare 3 distance metrics: 'euclidean', 'manhattan', 'minkowski'
# 2. For each metric with k=5:
    # - Train kNN
    # - Compute test accuracy
    # - Compute test AUC
# 3. Which metric works best?
# 4. Try the best metric with different k values

# Your code here

# %% [markdown]
# ## Exercise 3: Weighted vs. Unweighted

# %%
# TODO:
# 1. Train two models:
    # - kNN with weights='uniform' (standard)
    # - kNN with weights='distance' (closer neighbors vote more)
# 2. Use k=5 for both
# 3. Compare test accuracy
# 4. Does weighting help?

# Your code here

# %% [markdown]
# ## Exercise 4: Feature Importance
#
# Unlike tree-based models, kNN doesn't provide feature importance directly. But we can use this trick:

# %%
# TODO:
# 1. Train kNN baseline on all features
# 2. For each feature:
    # - Shuffle that feature and measure accuracy drop
    # - Features that drop accuracy when shuffled are important
# 3. Rank features by importance
# 4. Compare to RandomForest feature importances (from previous module)

# Your code here

# %% [markdown]
# ## Exercise 5: Scaling Impact

# %%
# TODO:
# 1. Compare kNN trained on scaled vs. unscaled data
# 2. For k = 1, 3, 5, 10, 20:
    # - Get accuracy without scaling
    # - Get accuracy with scaling
    # - Compute difference
# 3. How much does scaling help?
# 4. Which k values benefit most from scaling?

# Your code here
