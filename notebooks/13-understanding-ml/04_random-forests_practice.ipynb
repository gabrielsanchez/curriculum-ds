# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Random Forests - Practice
#
# Tune ensemble hyperparameters and interpret feature importance.

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

# %% [markdown]
# ## Exercise 1: n_estimators Sweet Spot

# %%
# TODO:
# 1. Load cancer data, split, prepare
# 2. Try n_estimators: 1, 5, 10, 25, 50, 100, 200, 500, 1000
# 3. For each:
    # - Train RandomForestClassifier
    # - Get test accuracy
# 4. Plot accuracy vs. n_estimators
# 5. At what point does increasing trees stop helping?

# Your code here

# %% [markdown]
# ## Exercise 2: max_depth and Overfitting

# %%
# TODO:
# 1. Fix n_estimators=100
# 2. Try max_depth: 5, 10, 15, 20, 30, None
# 3. For each depth:
    # - Get train and test accuracy
    # - Compute overfitting gap
# 4. Which depth minimizes overfitting?
# 5. Create visualization

# Your code here

# %% [markdown]
# ## Exercise 3: Feature Importance Ranking

# %%
# TODO:
# 1. Train RandomForestClassifier
# 2. Extract feature_importances_
# 3. Create ranking of all features by importance
# 4. Top 5 most important
# 5. Bottom 5 least important
# 6. Create a bar plot of top 15 features

# Your code here

# %% [markdown]
# ## Exercise 4: Bootstrap Variance Reduction

# %%
# TODO:
# 1. Train random forest with max_depth=20 (intentionally deep)
# 2. Compare:
    # - Single tree (max_depth=20)
    # - Random forest (100 trees, max_depth=20)
# 3. For each:
    # - Train/test accuracy
    # - Overfitting gap
# 4. How much does ensemble help with deep trees?

# Your code here

# %% [markdown]
# ## Exercise 5: GridSearchCV for Random Forests

# %%
# TODO:
# 1. Use GridSearchCV to find best:
    # - n_estimators: [50, 100, 200]
    # - max_depth: [10, 15, 20, None]
# 2. Use 5-fold cross-validation
# 3. Report best parameters
# 4. Report best CV score
# 5. Evaluate on test set

# Your code here
