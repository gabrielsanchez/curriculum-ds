# %% [markdown]
# # Module 1 Assessment — Introduction to Data Science (Solution)
#
# This notebook contains reference solutions. All tasks are completed with expected outputs shown as comments.

# %% [markdown]
# ## Task 1: Environment Verification
#
# Run the cell below. Confirm all five libraries print without error.

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import sklearn

print(f"Python:       {sys.version.split()[0]}")
print(f"pandas:       {pd.__version__}")
print(f"numpy:        {np.__version__}")
print(f"matplotlib:   {matplotlib.__version__}")
print(f"scikit-learn: {sklearn.__version__}")
print("\nEnvironment ready!")

# Expected output (versions may vary):
# Python:       3.10.12
# pandas:       2.1.4
# numpy:        1.26.4
# matplotlib:   3.8.2
# scikit-learn: 1.3.2
#
# Environment ready!

# %% [markdown]
# ## Task 2: Data Science in Your Own Words
#
# In the markdown cell below, write 3–5 sentences answering:
# - What is data science, in your own words?
# - Name one industry and describe one specific way data science is used there.
# - What do you personally hope to build or analyze by the end of this curriculum?

# %% [markdown]
# Data science is the practice of collecting, cleaning, and analyzing data to extract useful insights and support decision-making. It combines statistics, programming, and domain knowledge to turn raw information into actionable conclusions. In healthcare, data science is used to predict patient readmission risk, allowing hospitals to intervene early and reduce costs. By the end of this curriculum, I hope to build a model that predicts housing prices in my city using publicly available real estate data.

# %% [markdown]
# ## Task 3: Python Basics Check
#
# Complete the code cell below. Replace each `___` with your answer.

# %%
# 3a. Assign your name to a variable and print a greeting
name = "Alex"
print(f"Hello, {name}!")  # Hello, Alex!

# 3b. Create a list of three data science tools you learned about
tools = ["pandas", "numpy", "scikit-learn"]
print(f"Tools: {tools}")  # Tools: ['pandas', 'numpy', 'scikit-learn']

# 3c. Use a for loop to print each tool on its own line
for tool in tools:
    print(tool)
# pandas
# numpy
# scikit-learn

# 3d. Create a dictionary with keys 'name' and 'goal'
profile = {"name": name, "goal": "Learn data science"}
print(profile)  # {'name': 'Alex', 'goal': 'Learn data science'}

# 3e. Write a one-line conditional: assign 'expert' if len(tools) > 5, else 'beginner'
level = "expert" if len(tools) > 5 else "beginner"
print(f"Level: {level}")  # Level: beginner

# %% [markdown]
# ## Task 4: GitHub Workflow
#
# Follow these steps:
# 1. Complete all tasks in this notebook
# 2. Go to **File → Save a copy in GitHub**
# 3. Use commit message: `Complete Module 1 assessment`
# 4. Paste the GitHub URL of your notebook in the markdown cell below.

# %% [markdown]
# # https://github.com/your-username/your-repo/blob/main/module-assessment.ipynb

# %% [markdown]
# ## Task 5: Responsible AI Use
#
# In the markdown cell below, answer both questions (2–3 sentences each):
#
# **Question A:** You're stuck on a data cleaning error and have been debugging for 20 minutes. How would you use an AI assistant to help?
#
# **Question B:** Your instructor assigns a graded notebook exercise. What is the appropriate way to use AI tools while completing it?

# %% [markdown]
# **Question A:** After spending 20 minutes debugging, I would paste the relevant code and the full error message into the AI assistant and ask it to explain what the error means and suggest possible causes. I would read the explanation carefully and try to understand the fix before applying it, rather than copying code blindly. This approach uses AI as a learning tool — it helps me get unstuck while still building my own understanding.
#
# **Question B:** For a graded exercise, I would use AI tools only to clarify concepts or check my understanding of a specific function — not to generate the solution for me. I would write my own code first, and if I got stuck, I might ask the AI to explain a concept without asking it to solve the exact problem. Submitting AI-generated code as my own work without understanding it would undermine the purpose of the assignment and my own learning.
