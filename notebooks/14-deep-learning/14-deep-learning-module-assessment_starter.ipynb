# %% [markdown]
# # Save Your Work
#
# Before you begin, save a copy of this notebook to your Google Drive: **File > Save a copy in Drive**.
#
# # Module 14 Assessment — Deep Learning
#
# Build and compare deep learning architectures on Fashion-MNIST: a dense baseline, a CNN, and a regularized CNN.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Normalize pixel values to [0, 1]
X_train = X_train.astype("float32") / 255.0
X_test  = X_test.astype("float32")  / 255.0

# Class names
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print(f"Train: {X_train.shape}, Test: {X_test.shape}")
print(f"Classes: {class_names}")

# %% [markdown]
# ## Part 1: Dense Baseline
#
# ### Task 1: Build and Train a Dense Network
#
# Build a Sequential model:
# - `Flatten` (input: 28×28)
# - `Dense(256, activation='relu')`
# - `Dense(128, activation='relu')`
# - `Dense(10, activation='softmax')`
#
# Compile: `optimizer='adam'`, `loss='sparse_categorical_crossentropy'`, `metrics=['accuracy']`
#
# Train: 20 epochs, `validation_split=0.2`, `batch_size=64`
#
# Report test accuracy.

# %%
# Build dense model
# model_dense = keras.Sequential([...])
# model_dense.compile(...)
# history_dense = model_dense.fit(...)
# test_loss, test_acc = model_dense.evaluate(X_test, y_test)
# print(f"Dense baseline test accuracy: {test_acc:.4f}")

# %% [markdown]
# ### Task 2: Training Curves
#
# Plot training and validation accuracy (left) and training and validation loss (right) side-by-side.
#
# Write 2 sentences in the markdown cell below: does the model show signs of overfitting? At which epoch does it become apparent?

# %%
# Plot accuracy and loss curves
# fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# Your code here

# %% [markdown]
# *[Your overfitting observation here]*

# %% [markdown]
# ## Part 2: CNN Architecture
#
# ### Task 3: Build a CNN
#
# For the CNN, reshape input to include channel dimension:
# ```python
# X_train_cnn = X_train[..., np.newaxis]  # shape (60000, 28, 28, 1)
# X_test_cnn  = X_test[..., np.newaxis]
# ```
#
# Architecture:
# - `Conv2D(32, 3, activation='relu', padding='same')`
# - `MaxPooling2D(2)`
# - `Conv2D(64, 3, activation='relu', padding='same')`
# - `MaxPooling2D(2)`
# - `Flatten`
# - `Dense(128, activation='relu')`
# - `Dense(10, activation='softmax')`
#
# Train 20 epochs. Compare test accuracy with Task 1.

# %%
X_train_cnn = X_train[..., np.newaxis]
X_test_cnn  = X_test[..., np.newaxis]

# Build CNN model
# model_cnn = keras.Sequential([...])
# Your code here

# %% [markdown]
# ### Task 4: Apply Regularization
#
# Rebuild the CNN with:
# - `BatchNormalization()` after each `Conv2D`
# - `Dropout(0.3)` after the `Dense(128)` layer
# - `EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)`
#
# Train and report test accuracy and which epoch training stopped.

# %%
# Regularized CNN
# Your code here

# %% [markdown]
# ## Part 3: Analysis
#
# ### Task 5: Confusion Matrix
#
# Using the regularized CNN:
# 1. Compute predictions on the test set
# 2. Display the confusion matrix with class labels
# 3. Identify the two most commonly confused class pairs
# 4. Write 2 sentences in the markdown cell below explaining why those classes might be confused visually.

# %%
# y_pred = np.argmax(model_reg.predict(X_test_cnn), axis=1)
# Your confusion matrix code here

# %% [markdown]
# *[Your confusion analysis here]*

# %% [markdown]
# ### Task 6: Comparison Table
#
# Fill in your results:
#
# | Model | Test Accuracy | Epochs Trained |
# |-------|--------------|----------------|
# | Dense baseline | | 20 |
# | CNN (no regularization) | | 20 |
# | CNN + Dropout + BatchNorm + EarlyStopping | | |

# %% [markdown]
# ### Task 7: Reflection
#
# In the markdown cell below, answer:
# 1. Why does the CNN outperform the dense network on image data?
# 2. What does Dropout prevent during training?
# 3. When would you prefer EarlyStopping over training for a fixed number of epochs?

# %% [markdown]
# *[Your reflection answers here]*
