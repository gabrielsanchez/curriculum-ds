# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Multi-class Classification - Practice
#
# Build and evaluate multi-class classifiers on different datasets.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## Exercise 1: Train on Wine Dataset
#
# Build a classifier to predict wine type (3 classes).

# %%
# TODO:
# 1. Load wine dataset
# 2. Create X and y
# 3. Print class names
# 4. Split 80/20 with stratification
# 5. Scale features
# 6. Train logistic regression
# 7. Print accuracy

# Your code here

# %% [markdown]
# ## Exercise 2: Analyze Confusion Matrix
#
# Understand what the model gets right and wrong.

# %%
# TODO:
# 1. Compute confusion matrix
# 2. Print it with proper formatting
# 3. For each class, identify:
    # - How many correct predictions (diagonal)
    # - Which class it gets confused with most
# 4. Are any classes harder to predict?

# Your code here

# %% [markdown]
# ## Exercise 3: Per-class Metrics
#
# Print and interpret classification report.

# %%
# TODO:
# 1. Get predictions
# 2. Print classification report with target names
# 3. Which class has the highest recall?
# 4. Which class has the lowest f1-score?
# 5. How do macro and weighted averages compare?

# Your code here

# %% [markdown]
# ## Exercise 4: Imbalanced Multi-class
#
# Create an imbalanced dataset and see how it affects metrics.

# %%
# TODO:
# 1. Load wine dataset
# 2. Create an imbalanced version:
    # Keep all class 0 samples
    # Keep all class 1 samples
    # Keep only 20% of class 2 samples
# 3. Train on imbalanced data
# 4. Compare macro vs. weighted average F1
# 5. Which is more meaningful for this imbalanced case?

# Your code here

# %% [markdown]
# ## Exercise 5: Probability Thresholds
#
# Scikit-learn's default is to predict the class with highest probability. What if you enforce high confidence?

# %%
# TODO:
# 1. Get probability predictions
# 2. For each sample, get max probability (confidence)
# 3. Filter to only samples where max_prob >= 0.8 (high confidence)
# 4. Compute accuracy on high-confidence predictions only
# 5. How does accuracy change when requiring high confidence?

# Your code here
