# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Multi-label Classification - Practice
#
# Build and evaluate multi-label classifiers.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import hamming_loss, accuracy_score

# %% [markdown]
# ## Exercise 1: Create Multi-label Dataset
#
# Build a realistic multi-label dataset for article tagging.

# %%
# TODO:
# 1. Create X: 200 samples, 8 features (article characteristics)
# 2. Create y: 200 samples, 4 labels (tags)
    # Each article has 0-4 tags
# 3. Print shape of X and y
# 4. Print how many articles have each number of tags (0, 1, 2, 3, 4)

# Your code here

# %% [markdown]
# ## Exercise 2: Train Multi-label Classifier

# %%
# TODO:
# 1. Split into 80/20
# 2. Scale features
# 3. Train MultiOutputClassifier with LogisticRegression
# 4. Get predictions
# 5. Compute Hamming Loss
# 6. Compute Jaccard Similarity

# Your code here

# %% [markdown]
# ## Exercise 3: Understand the Metrics

# %%
# TODO:
# 1. Compute label-by-label accuracy
# 2. Compute Hamming loss
# 3. Compute Jaccard similarity
# 4. Compare:
    # - Which label is easiest to predict?
    # - Which is hardest?
    # - Is Jaccard >= Hamming? Why or why not?

# Your code here

# %% [markdown]
# ## Exercise 4: Exact Match vs. Partial Match
#
# Some applications tolerate partial mismatches better than others.

# %%
# TODO:
# 1. Compute Jaccard similarity (exact match required)
# 2. Compute Hamming loss (individual label accuracy)
# 3. For each sample, count:
    # - How many labels are correct
    # - How many are completely wrong
# 4. Discuss:
    # - Would a movie recommendation system care more about Hamming or Jaccard?
    # - What about medical diagnosis (multiple diseases per patient)?

# %% [markdown]
# ## Exercise 5: Label Imbalance
#
# Some labels may be rarer than others.

# %%
# TODO:
# 1. Using your multi-label dataset from Exercise 1:
# 2. Count how many samples have each label
# 3. Create an imbalanced version:
    # - Keep all samples with label 0
    # - Keep 50% of samples with label 1
    # - Keep 20% of samples with label 2
    # - Keep 80% of samples with label 3 (rare label)
# 4. Train on original and imbalanced
# 5. Compare per-label accuracy
# 6. Which labels are harder to predict on imbalanced data?
