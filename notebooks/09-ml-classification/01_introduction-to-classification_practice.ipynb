# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Introduction to Classification - Practice
#
# Classify problems and identify classification types.

# %% [markdown]
# ## Exercise 1: Classify These Problems
#
# For each scenario, identify:
# 1. **Classification or Regression?**
# 2. **If classification: Binary, Multi-class, or Multi-label?**
# 3. **What are the classes/categories?**

# %% [markdown]
# ### A. Predicting Customer Support Priority
# A company receives support tickets and wants to automatically categorize them as: "urgent", "standard", or "low priority".
#
# - **Classification or Regression?** ___________
# - **Type?** ___________
# - **Classes?** ___________

# %% [markdown]
# ### B. Article Tagging
# Medium wants to tag articles with: "Machine Learning", "Data Science", "Business", "Technology", etc. Each article can have 1 or more tags.
#
# - **Classification or Regression?** ___________
# - **Type?** ___________
# - **Classes?** ___________

# %% [markdown]
# ### C. Plant Disease Detection
# A farming app analyzes photos of crop leaves to predict: "Healthy", "Powdery Mildew", "Leaf Spot", or "Rust".
#
# - **Classification or Regression?** ___________
# - **Type?** ___________
# - **Classes?** ___________

# %% [markdown]
# ### D. Approving Loan Applications
# A bank decides: approve or deny a loan application (two possible outcomes).
#
# - **Classification or Regression?** ___________
# - **Type?** ___________
# - **Classes?** ___________

# %% [markdown]
# ### E. Predicting Quarterly Revenue
# A company estimates next quarter's revenue in dollars ($2.5M, $3.1M, etc.).
#
# - **Classification or Regression?** ___________
# - **Type?** ___________
# - **Classes?** ___________

# %% [markdown]
# ### F. Handwritten Digit Recognition
# Recognize a handwritten digit as one of: 0, 1, 2, 3, 4, 5, 6, 7, 8, or 9.
#
# - **Classification or Regression?** ___________
# - **Type?** ___________
# - **Classes?** ___________

# %% [markdown]
# ## Exercise 2: Positive vs. Negative Class
#
# For each binary classification problem, identify the **positive class** (the outcome you care most about detecting):
#
# 1. **Cancer screening:** Positive = ___________ | Negative = ___________
# 2. **Fraud detection:** Positive = ___________ | Negative = ___________
# 3. **Customer churn:** Positive = ___________ | Negative = ___________
# 4. **Spam filtering:** Positive = ___________ | Negative = ___________

# %% [markdown]
# ## Exercise 3: Decision Boundaries
#
# **Scenario:** You have 2 features (Age, Income) and want to predict Loan Approval (Yes/No).
#
# ```
# Income
#   ↑
#   |  Approved (*)     Approved (*)
#   |  *   *   *        *   *   * |←-- decision boundary
#   |  *   *            *   * ----
#   |-------*----*----*-------*---
#   |          *   *   *
#   |        Denied (o)
#   |_____________________→ Age
# ```
#
# **TODO:**
# 1. In words, describe where the decision boundary is.
# 2. If a new applicant is 35 years old with $150k income, which side of the boundary are they on?
# 3. Why does the boundary look diagonal instead of vertical or horizontal?

# %% [markdown]
# ## Exercise 4: Probability vs. Hard Labels
#
# A spam classifier on emails outputs probabilities:
#
# - Email A: Probability = 0.92 (92% spam) → **Prediction: _____**
# - Email B: Probability = 0.48 (48% spam) → **Prediction: _____**
# - Email C: Probability = 0.51 (51% spam) → **Prediction: _____**
# - Email D: Probability = 0.05 (5% spam) → **Prediction: _____**
#
# (Using default threshold of 0.5)
#
# **Bonus:** What if you change the threshold to 0.8 (only flag emails you're very sure about)? Which emails would be flagged then?

# %% [markdown]
# ## Exercise 5: The Classification Pipeline
#
# You're building a system to predict if a movie will be a box office success. Put these steps in order:
#
# - [ ] Evaluate on test set using accuracy, precision, recall
# - [ ] Split data into 80% train, 20% test
# - [ ] Clean data and handle missing values
# - [ ] Train a logistic regression classifier
# - [ ] Scale numeric features
# - [ ] Adjust features or algorithm based on results
#
# **Correct order:** 1. ___ → 2. ___ → 3. ___ → 4. ___ → 5. ___ → 6. ___
