# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Binary Classification - Practice
#
# Build binary classifiers and evaluate them on different datasets.

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# %% [markdown]
# ## Exercise 1: Train on Breast Cancer Dataset
#
# Build a binary classifier to predict cancer diagnosis.

# %%
# TODO:
# 1. Load the breast cancer dataset
# 2. Split into train/test (80/20)
# 3. Scale the features
# 4. Train logistic regression
# 5. Compute predictions
# 6. Print accuracy, precision, recall, F1

# Your code here

# %% [markdown]
# ## Exercise 2: Understand the Confusion Matrix
#
# Using the model from Exercise 1:

# %%
# TODO:
# 1. Compute the confusion matrix
# 2. Extract TP, FP, TN, FN
# 3. Manually calculate: accuracy, precision, recall
# 4. Verify they match sklearn's scores

# Your code here

# %% [markdown]
# ## Exercise 3: Precision vs. Recall Scenario
#
# **Scenario:** Predicting cancer is a medical diagnosis. Which metric is more important?
#
# 1. **High precision, low recall:** We rarely tell someone they have cancer unless we're sure, but we miss many actual cases.
#    - **Risk:** Patients with cancer left untreated
#
# 2. **High recall, low precision:** We flag everyone who might have cancer, even if unsure.
#    - **Risk:** False alarms, unnecessary follow-up tests
#
# **TODO:** Which is better for cancer diagnosis and why?

# %% [markdown]
# ## Exercise 4: Threshold Adjustment
#
# Adjust the classification threshold and see how it affects metrics.

# %%
# TODO:
# 1. Get probability predictions from your model
# 2. Try different thresholds: 0.3, 0.5, 0.7
# 3. For each threshold:
    # Convert probabilities to predictions
    # Compute precision and recall
# 4. What pattern do you notice?

# Your code here

# %% [markdown]
# ## Exercise 5: Compare F1 Scores
#
# Create two classifiers with different settings and compare F1 scores.

# %%
# TODO:
# 1. Train logistic regression with max_iter=100
# 2. Train logistic regression with max_iter=10000
# 3. Compute F1 scores for both
# 4. Do they differ? Why or why not?

# Your code here
