# %% [markdown]
# # Save Your Work
#
# Before you begin, save a copy of this notebook to your Google Drive: **File > Save a copy in Drive**.
#
# # Module 15 Assessment — NLP
#
# Build a complete text classification pipeline on the 20 Newsgroups dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score

categories = ['sci.med', 'sci.space', 'rec.sport.hockey', 'talk.politics.guns']

train_data = fetch_20newsgroups(subset='train', categories=categories,
                                 remove=('headers', 'footers', 'quotes'))
test_data  = fetch_20newsgroups(subset='test',  categories=categories,
                                 remove=('headers', 'footers', 'quotes'))

print(f"Train: {len(train_data.data)} documents")
print(f"Test:  {len(test_data.data)} documents")
print(f"Categories: {train_data.target_names}")

# %% [markdown]
# ## Task 1: Exploratory Text Analysis
#
# For each of the 4 categories:
# 1. Count number of training documents
# 2. Compute average document length in characters
# 3. Print the 5 most common words (excluding stopwords)
#
# Write 2 sentences in the markdown cell below describing differences between categories.

# %%
# Your exploratory code here
# Hint: use Counter and string operations, or a simple CountVectorizer

# %% [markdown]
# *[Your category analysis here]*

# %% [markdown]
# ## Task 2: TF-IDF + Logistic Regression Baseline
#
# Build a Pipeline:
# - `TfidfVectorizer(max_features=5000, stop_words='english', ngram_range=(1,2))`
# - `LogisticRegression(max_iter=1000, random_state=42)`
#
# Train on `train_data`, evaluate on `test_data`. Print the full classification report.

# %%
# Your TF-IDF + LR pipeline here

# %% [markdown]
# ## Task 3: Preprocessing Ablation
#
# Compare three TF-IDF configurations with the same LogisticRegression:
#
# | Configuration | Accuracy |
# |---------------|----------|
# | No preprocessing (default TfidfVectorizer) | |
# | stop_words='english' | |
# | stop_words='english', min_df=5 | |
#
# Which configuration performs best? Write 1 sentence.

# %%
# Test all 3 configurations
# Your code here

# %% [markdown]
# *[Your best configuration observation here]*

# %% [markdown]
# ## Task 4: Naive Bayes Comparison
#
# Build a Pipeline with `TfidfVectorizer(stop_words='english')` and `MultinomialNB()`.
#
# Fill in the table:
#
# | Model | Accuracy | sci.med F1 | sci.space F1 | rec.sport.hockey F1 | talk.politics.guns F1 |
# |-------|----------|-----------|-------------|---------------------|----------------------|
# | Logistic Regression | | | | | |
# | Naive Bayes | | | | | |

# %%
# Your Naive Bayes pipeline here

# %% [markdown]
# ## Task 5: Error Analysis
#
# For the best-performing model, identify 3 misclassified test documents.
# Print for each: first 200 characters, true label, predicted label.
# Write 1 sentence per document explaining the likely reason for misclassification.

# %%
# Your error analysis code here

# %% [markdown]
# ## Task 6: Reflection
#
# Answer in the markdown cell below:
# 1. What information does TF-IDF capture that raw term counts do not?
# 2. In what scenario would you choose DistilBERT over TF-IDF + Logistic Regression?
# 3. Why was it important to remove 'headers', 'footers', and 'quotes' from the documents?

# %% [markdown]
# *[Your reflection here]*
