# %% [markdown]
# # Functions - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %% [markdown]
# ## Exercise 1: Currency Converter
#
# Write a function `convert_usd_to_eur(usd_amount)` that:
# 1. Takes an amount in USD as a parameter
# 2. Converts it to EUR using an exchange rate of 0.92
# 3. Returns the converted amount
#
# Test the function with at least 3 different amounts.

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Classify a Number
#
# Write a function `classify_number(num)` that:
# 1. Takes an integer as a parameter
# 2. Returns "even" if the number is even
# 3. Returns "odd" if the number is odd
#
# Test with at least 5 different numbers (both positive and negative).

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Calculate Order Total
#
# Write a function `calculate_total(price, quantity, discount=0)` that:
# 1. Takes three parameters: price, quantity, and an optional discount
# 2. Calculates subtotal = price × quantity
# 3. Applies the discount as a percentage
# 4. Returns the final total
#
# Test with:
# - Item cost $15, quantity 3, no discount
# - Item cost $20, quantity 2, 10% discount
# - Item cost $50, quantity 1, 20% discount

# %%
# Add your code here

# %% [markdown]
# ## Exercise 4: Validate Password
#
# Write a function `validate_password(password)` that:
# 1. Returns "Valid" if the password has at least 8 characters
# 2. Returns "Too short" if it has fewer than 8 characters
#
# Test with at least 4 different passwords.

# %%
# Add your code here
