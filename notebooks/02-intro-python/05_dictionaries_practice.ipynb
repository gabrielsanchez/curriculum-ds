# %% [markdown]
# # Dictionaries - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %% [markdown]
# ## Exercise 1: Create and Modify a Movie Dictionary
#
# Create a dictionary for a movie with the following keys:
# - `title`: "The Matrix"
# - `release_year`: 1999
# - `director`: "The Wachowskis"
# - `rating`: 8.7
#
# Then:
# 1. Print the dictionary
# 2. Access and print the movie title
# 3. Add a new key `genre` with value "Sci-Fi"
# 4. Update the rating to 8.8
# 5. Delete the `director` key
# 6. Print the final dictionary

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Process Restaurant Information
#
# Create a dictionary for a restaurant:
# ```python
# restaurant = {
#     "name": "Pasta Place",
#     "cuisine": "Italian",
#     "hours_open": 11,
#     "hours_close": 22,
#     "reservations_required": False
# }
# ```
#
# Using `.get()`, safely retrieve:
# 1. The restaurant's cuisine
# 2. The chef's name (which doesn't exist - provide a default)
# 3. The phone number (which doesn't exist - provide a default)
# 4. Add the phone number as a new key
# 5. Print all key-value pairs using a loop

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Build an Inventory Dictionary
#
# Create an empty dictionary called `inventory`. Then add items with quantities:
# - "apples": 25
# - "oranges": 18
# - "bananas": 30
# - "grapes": 12
#
# Then:
# 1. Print the entire inventory
# 2. Update the apple quantity to 20
# 3. Add a new item "strawberries": 15
# 4. Remove "grapes" from the inventory
# 5. Print all items and their quantities in a formatted way
# 6. Print the number of different items

# %%
# Add your code here
