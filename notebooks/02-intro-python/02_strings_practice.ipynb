# %% [markdown]
# # Strings - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %% [markdown]
# ## Exercise 1: Concatenate a Recipe Name
#
# Create three variables:
# - `cuisine` = a type of cuisine (e.g., "Italian")
# - `dish` = a dish name (e.g., "Pasta")
# - `ingredient` = a main ingredient (e.g., "Tomato")
#
# Use string concatenation to create and print: `"{cuisine} {dish} with {ingredient}"`
#
# Also create the same message using an f-string.

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Extract Characters from a Code
#
# Create a string representing a product code: `"PROD2024XYZ"`
#
# Extract and print:
# 1. The first 4 characters
# 2. The middle 4 characters
# 3. The last 3 characters
# 4. Every other character starting from index 0

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Transform User Input
#
# Create a string: `"  welcome to data science  "`
#
# Using string methods, process this string to:
# 1. Remove leading/trailing whitespace (use `.strip()`)
# 2. Convert to uppercase
# 3. Replace "data science" with "ML"
# 4. Split the result into a list of words
#
# Print the result of each step.

# %%
# Add your code here
