# %% [markdown]
# # Introduction to Python: Variables and Data Types - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %% [markdown]
# ## Exercise 1: Create Variables for a Book
#
# Create variables to store information about a book. Declare variables for:
# - `title` (a string)
# - `author` (a string)
# - `published_year` (an integer)
# - `rating` (a float)
# - `is_bestseller` (a boolean)
#
# Then print each variable.

# %%
# Declare your variables here

# %% [markdown]
# ## Exercise 2: Update and Print Variables
#
# Create variables representing a movie:
# - `movie_name` (string)
# - `runtime_minutes` (integer)
# - `budget_millions` (float)
#
# Then update `runtime_minutes` to a new value and print all three variables.

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Check Data Types
#
# Create variables for:
# - A product name
# - A product price
# - Number of items in stock
# - Whether the item is on sale
#
# Use `type()` to print the data type of each variable.

# %%
# Add your code here
