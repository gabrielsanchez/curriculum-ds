# %% [markdown]
# # Lists - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %% [markdown]
# ## Exercise 1: Manage a Shopping List
#
# Create a list of grocery items: `["milk", "bread", "eggs", "cheese"]`
#
# Perform the following operations:
# 1. Print the list
# 2. Print the length of the list
# 3. Print the first item
# 4. Print the last item
# 5. Replace "cheese" with "butter"
# 6. Append "yogurt" to the list
# 7. Remove "bread" from the list
# 8. Print the final list

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Extract and Modify Temperature Data
#
# Create a list of daily temperatures: `[72, 75, 71, 78, 80, 82, 79]`
#
# Use slicing and methods to:
# 1. Extract the first 3 days' temperatures
# 2. Extract temperatures from day 4 onward
# 3. Extract every other day's temperature
# 4. Find and print the minimum and maximum temperatures (use `.min()` and `.max()` or create a new list and sort)
# 5. Add a new temperature reading at the end
# 6. Print the sorted temperatures

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Build and Modify a Course List
#
# Create an empty list called `my_courses`. Then:
# 1. Append "Python 101" to the list
# 2. Append "Statistics" to the list
# 3. Append "Data Visualization" to the list
# 4. Insert "Machine Learning" at index 1 (use `.insert(index, value)`)
# 5. Remove the last course from the list (use `.pop()`)
# 6. Print the final list
# 7. Print the length of the list
# 8. Print the first and last courses

# %%
# Add your code here
