# %% [markdown]
# # Conditional Logic - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %% [markdown]
# ## Exercise 1: Ticket Eligibility
#
# Create variables for a person's age. Write an `if`/`elif`/`else` statement that prints:
# - "Child ticket" if age is less than 12
# - "Youth ticket" if age is between 12 and 17 (inclusive)
# - "Adult ticket" if age is 18 or older
#
# Test your code with at least 3 different ages.

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Enrollment Status
#
# Create variables:
# - `has_completed_prerequisites` (boolean)
# - `gpa` (float between 0 and 4.0)
#
# Write an `if`/`else` statement that prints:
# - "You can enroll in the course." if both conditions are met: prerequisites completed AND GPA is 2.0 or higher
# - "You cannot enroll. Please meet all requirements." otherwise
#
# Test with different combinations.

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Discount Calculation
#
# Create variables:
# - `purchase_amount` (float)
# - `is_member` (boolean)
#
# Write conditions to print the discount:
# - "5% discount" if purchase amount is $50-99 and NOT a member
# - "10% discount" if purchase amount is $100-199 and NOT a member
# - "15% discount" if purchase amount is $200+ and NOT a member
# - "10% discount" if IS a member and purchase amount is $50-99
# - "15% discount" if IS a member and purchase amount is $100-199
# - "20% discount" if IS a member and purchase amount is $200+
# - "No discount" otherwise
#
# Test with at least 4 different scenarios.

# %%
# Add your code here
