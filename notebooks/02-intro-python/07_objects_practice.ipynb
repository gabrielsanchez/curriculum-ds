# %% [markdown]
# # Objects - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %% [markdown]
# ## Exercise 1: Create a Book Class
#
# Create a `Book` class with:
# 1. Attributes: `title`, `author`, `pages`, `is_read` (boolean)
# 2. A method `mark_read()` that sets `is_read` to `True`
# 3. A method `get_info()` that returns a formatted string with book details
#
# Create at least 2 book objects, print their info, mark one as read, and print again.

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Create a Bank Account Class
#
# Create a `BankAccount` class with:
# 1. Attributes: `account_holder`, `balance`
# 2. A method `deposit(amount)` that adds to the balance
# 3. A method `withdraw(amount)` that subtracts from the balance (if sufficient funds exist)
# 4. A method `get_balance()` that returns the current balance
#
# Test by:
# - Creating an account with an initial balance
# - Making deposits and withdrawals
# - Printing the balance after each transaction

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Create a Pet Class
#
# Create a `Pet` class with:
# 1. Attributes: `name`, `species`, `age`, `energy` (0-100 scale)
# 2. A method `sleep()` that increases energy by 20 (max 100)
# 3. A method `play()` that decreases energy by 15 (minimum 0)
# 4. A method `get_status()` that returns the pet's current status as a string
#
# Test by:
# - Creating a pet
# - Playing with the pet multiple times
# - Having the pet sleep
# - Printing the status after each action

# %%
# Add your code here
