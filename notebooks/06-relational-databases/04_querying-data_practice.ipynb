# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Querying Data - Practice
#
# Write SELECT queries with various filters and conditions.

# %%
import sqlite3

# Create a test database for practice
conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

# %% [markdown]
# ## Setup: Create a sample dataset

# %%
# Create sales table
cursor.execute("""
    CREATE TABLE sales (
        sale_id INTEGER PRIMARY KEY,
        product TEXT,
        category TEXT,
        amount REAL,
        region TEXT,
        date TEXT
    )
""")

# Insert sample sales data
data = [
    (1, 'Laptop', 'Electronics', 1200, 'North', '2024-01-10'),
    (2, 'Mouse', 'Electronics', 25, 'South', '2024-01-11'),
    (3, 'Desk', 'Furniture', 300, 'North', '2024-01-12'),
    (4, 'Chair', 'Furniture', 150, 'East', '2024-01-13'),
    (5, 'Monitor', 'Electronics', 350, 'West', '2024-01-14'),
    (6, 'Keyboard', 'Electronics', 80, 'North', '2024-01-15'),
    (7, 'Bookshelf', 'Furniture', 200, 'South', '2024-01-16'),
]

cursor.executemany("INSERT INTO sales VALUES (?, ?, ?, ?, ?, ?)", data)
conn.commit()

# %% [markdown]
# ## Exercise 1: Basic WHERE queries

# %%
# TODO: Write queries to answer these questions
# 1. Get all Electronics sales
# 2. Get all sales over $200
# 3. Get all sales from the North region
# 4. Get sales less than $100

# Your code here

# %% [markdown]
# ## Exercise 2: Pattern matching with LIKE

# %%
# TODO: Write LIKE queries
# 1. Get products starting with 'M'
# 2. Get products ending with 'e'
# 3. Get products containing 'chair' (case-insensitive)

# Your code here

# %% [markdown]
# ## Exercise 3: Multiple conditions with AND/OR

# %%
# TODO: Write complex WHERE queries
# 1. Get Electronics in North region
# 2. Get Furniture OR sales > $200
# 3. Get sells over $100 in North and East regions

# Your code here

# %% [markdown]
# ## Exercise 4: IN, BETWEEN, and DISTINCT

# %%
# TODO: Use IN, BETWEEN, and DISTINCT
# 1. Use IN to get sales from specific regions
# 2. Use BETWEEN to get sales between $100 and $500
# 3. Get DISTINCT categories
# 4. Get DISTINCT regions

# Your code here
