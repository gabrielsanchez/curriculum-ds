# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Introduction to SQL - Practice
#
# Test your understanding of SQL and relational databases.

# %% [markdown]
# ## Exercise 1: Identify Components
#
# Consider this library database:
#
# **members table:**
# | member_id | name      | join_date  |
# |-----------|-----------|----------|
# | 1         | Alice     | 2023-01-15 |
# | 2         | Bob       | 2023-03-20 |
# | 3         | Carol     | 2023-06-10 |
#
# **books table:**
# | book_id | title              | author       | year |
# |---------|-------------------|-------------|------|
# | 101     | Python Basics     | John Smith  | 2020 |
# | 102     | Data Science 101  | Jane Doe    | 2021 |
# | 103     | Web Development   | Bob Johnson | 2022 |
#
# **checkouts table:**
# | checkout_id | member_id | book_id | checkout_date |
# |-------------|-----------|---------|---------------|
# | 1           | 1         | 101     | 2024-01-10    |
# | 2           | 2         | 102     | 2024-01-12    |
# | 3           | 1         | 103     | 2024-01-15    |

# %% [markdown]
# ### TODO: Answer these questions
# 1. What is the primary key of the `members` table?
# 2. What is the foreign key in the `checkouts` table?
# 3. How many rows are in the `books` table?
# 4. How many columns are in the `members` table?
# 5. Which member (by name) checked out the most books?

# %% [markdown]
# ## Exercise 2: Schema Design
#
# Design a simple database for an online store:
# - Store information about **products** (id, name, price, quantity_in_stock)
# - Store information about **customers** (id, name, email, city)
# - Track **orders** connecting customers to products
#
# ### TODO: Plan your schema
# 1. What would be the primary key for each table?
# 2. What foreign keys would you need?
# 3. What data types would each column have?
# 4. Write out the three table structures (don't execute, just plan)

# %% [markdown]
# ## Exercise 3: Match SQL Statements to Descriptions
#
# Which SQL statement would you use for each task?
#
# **Statements:**
# - A: `CREATE TABLE users ...`
# - B: `SELECT name FROM customers ...`
# - C: `INSERT INTO orders ...`
# - D: `UPDATE products SET price = ...`
# - E: `DELETE FROM history WHERE ...`
#
# **Tasks:**
# 1. Show all customer names in the database: **___**
# 2. Add a new order to the system: **___**
# 3. Create a new table for storing user data: **___**
# 4. Change a product's price: **___**
# 5. Remove old records from a history table: **___**

# %% [markdown]
# ## Exercise 4: Translate Business Questions to SQL
#
# Using the library database from Exercise 1, write the SQL structure for these questions (don't worry about exact syntax, just outline the approach):
#
# 1. "Who is Alice and when did she join?" - Use **SELECT** from which table?
# 2. "What books were checked out on 2024-01-15?" - Which table(s) would you need?
# 3. "Which member checked out the most books?" - What would you need to **count** or **group by**?
