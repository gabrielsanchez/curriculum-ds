# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Setting Up SQLite - Practice
#
# Create databases and practice the SQLite workflow.

# %%
import sqlite3

# %% [markdown]
# ## Exercise 1: Create an In-Memory Database
#
# Create a simple movie database with a `movies` table.

# %%
# TODO: Create connection to in-memory database
# TODO: Create cursor
# TODO: Create a movies table with columns:
#       - movie_id (INTEGER PRIMARY KEY)
#       - title (TEXT NOT NULL)
#       - genre (TEXT)
#       - year (INTEGER)
# TODO: Commit changes

# Your code here

# %%
# TODO: Insert 3 sample movies into the table
# Examples: "The Matrix" (Sci-Fi, 1999), "Inception" (Sci-Fi, 2010), "Titanic" (Romance, 1997)
# Remember to commit changes

# Your code here

# %%
# TODO: Query to show all movies and print them
# Hint: Use SELECT * FROM movies, then fetchall()

# Your code here

# %% [markdown]
# ## Exercise 2: Multiple Tables
#
# Create a simple library system with `authors` and `books` tables.

# %%
# TODO: Create a new connection/cursor for this exercise
# TODO: Create an authors table:
#       - author_id (INTEGER PRIMARY KEY)
#       - name (TEXT NOT NULL)
# TODO: Create a books table:
#       - book_id (INTEGER PRIMARY KEY)
#       - title (TEXT NOT NULL)
#       - author_id (INTEGER) - this will be a foreign key
#       - published_year (INTEGER)

# Your code here

# %%
# TODO: Insert sample data
# Insert 2 authors
# Insert 3 books (make sure author_id matches)

# Your code here

# %%
# TODO: Query and display all books

# Your code here

# %% [markdown]
# ## Exercise 3: Using a File Database
#
# Create a persistent database file (not in-memory).

# %%
# TODO: Connect to a file database called "practice.db"
# TODO: Create a products table:
#       - product_id (INTEGER PRIMARY KEY)
#       - product_name (TEXT NOT NULL)
#       - price (REAL)
#       - quantity (INTEGER)

# Your code here

# %%
# TODO: Insert 4 sample products
# Examples: Laptop ($1000, 5 units), Mouse ($25, 50 units), etc.

# Your code here

# %%
# TODO: Query and display all data

# Your code here
