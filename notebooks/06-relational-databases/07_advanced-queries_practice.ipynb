# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Advanced Queries - Practice
#
# Work with subqueries, CASE expressions, and transformations.

# %%
import sqlite3

conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

# %% [markdown]
# ## Setup: Employee data

# %%
cursor.execute("""
    CREATE TABLE employees (
        emp_id INTEGER PRIMARY KEY,
        name TEXT,
        salary REAL,
        department TEXT,
        hire_date TEXT
    )
""")

data = [
    (1, 'Alice', 75000, 'Engineering', '2022-01-15'),
    (2, 'Bob', 65000, 'Marketing', '2021-05-20'),
    (3, 'Charlie', 80000, 'Engineering', '2020-03-10'),
    (4, 'Diana', 55000, 'Sales', '2023-06-01'),
    (5, 'Eve', 70000, 'Engineering', '2022-09-15'),
]

cursor.executemany("INSERT INTO employees VALUES (?, ?, ?, ?, ?)", data)
conn.commit()

# %% [markdown]
# ## Exercise 1: CASE WHEN expressions

# %%
# TODO: Use CASE to classify salaries
# Create salary tiers: Under 60K (Junior), 60-75K (Mid), Over 75K (Senior)
# Show employee names, departments, salaries, and tiers

# Your code here

# %% [markdown]
# ## Exercise 2: Subqueries

# %%
# TODO: Use subqueries
# 1. Find employees earning more than average
# 2. Find employees from departments with avg salary > 70000
# 3. Find the highest paid employee per department

# Your code here

# %% [markdown]
# ## Exercise 3: String functions

# %%
# TODO: Use string functions
# 1. Convert names to uppercase
# 2. Extract year from hire_date
# 3. Find employees whose name starts with 'A'
# 4. Get initial of first letter and department

# Your code here

# %% [markdown]
# ## Exercise 4: Combine all techniques

# %%
# TODO: Complex query combining techniques
# Create a report with:
# - Employee name (uppercase)
# - Department
# - Salary
# - Salary tier (CASE WHEN: Over avg = High, Under = Low)
# - Years employed (based on hire_date)
# - Order by department, then salary DESC

# Your code here
