# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Tables, Data Types, and Fields - Practice
#
# Design and create tables with appropriate constraints.

# %%
import sqlite3

# %% [markdown]
# ## Exercise 1: Create a Restaurant Database
#
# Design and create tables for a restaurant reservation system.

# %%
# TODO: Create connection and cursor
# TODO: Create a restaurants table:
#       - restaurant_id (INTEGER PRIMARY KEY)
#       - name (TEXT NOT NULL, UNIQUE)
#       - cuisine (TEXT)
#       - rating (REAL CHECK(rating >= 0 AND rating <= 5))
#       - phone (TEXT)

# Your code here

# %%
# TODO: Create a reservations table:
#       - reservation_id (INTEGER PRIMARY KEY)
#       - restaurant_id (INTEGER with FOREIGN KEY)
#       - customer_name (TEXT NOT NULL)
#       - reservation_date (TEXT NOT NULL)
#       - party_size (INTEGER CHECK(party_size > 0))
#       - phone (TEXT)

# Your code here

# %%
# TODO: Insert 3 restaurants and 5 reservations
# Make sure reservation restaurant_id values match existing restaurants

# Your code here

# %%
# TODO: Display all restaurants and reservations

# Your code here

# %% [markdown]
# ## Exercise 2: E-commerce Product Database

# %%
# TODO: Create new connection/cursor
# TODO: Create a categories table:
#       - category_id (INTEGER PRIMARY KEY)
#       - category_name (TEXT NOT NULL, UNIQUE)

# TODO: Create a products table:
#       - product_id (INTEGER PRIMARY KEY)
#       - product_name (TEXT NOT NULL)
#       - category_id (INTEGER with FOREIGN KEY)
#       - price (REAL CHECK(price > 0))
#       - quantity_in_stock (INTEGER DEFAULT 0)
#       - date_added (TEXT DEFAULT CURRENT_DATE)

# Your code here

# %%
# TODO: Insert 3 categories and 6 products (2 per category)

# Your code here

# %%
# TODO: Display all products (show product_name, category_id, price, quantity_in_stock)

# Your code here

# %% [markdown]
# ## Exercise 3: Test Constraints

# %%
# TODO: Try to insert invalid data and catch the error
# Example: Insert a product with negative price (should violate CHECK constraint)
# Or duplicate category name (should violate UNIQUE constraint)

# Your code here
