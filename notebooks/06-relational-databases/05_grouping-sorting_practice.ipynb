# %% [markdown]
# # Save Your Work
#
# Before starting, save this notebook to your Google Drive:
# 1. Click **File** → **Save a copy in Drive**
# 2. The copy will open automatically
# 3. Work in the Google Drive copy from now on
#
# ---
#
# # Grouping and Sorting - Practice
#
# Use GROUP BY, ORDER BY, and aggregate functions.

# %%
import sqlite3

conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

# %% [markdown]
# ## Setup: Sales data

# %%
cursor.execute("""
    CREATE TABLE sales (
        sale_id INTEGER PRIMARY KEY,
        salesperson TEXT,
        region TEXT,
        product TEXT,
        amount REAL,
        date TEXT
    )
""")

data = [
    (1, 'Alice', 'North', 'Widget A', 100, '2024-01-10'),
    (2, 'Bob', 'South', 'Widget B', 150, '2024-01-11'),
    (3, 'Alice', 'North', 'Widget A', 120, '2024-01-12'),
    (4, 'Charlie', 'East', 'Widget C', 200, '2024-01-13'),
    (5, 'Bob', 'South', 'Widget A', 130, '2024-01-14'),
    (6, 'Alice', 'North', 'Widget B', 110, '2024-01-15'),
    (7, 'Charlie', 'East', 'Widget A', 180, '2024-01-16'),
]

cursor.executemany("INSERT INTO sales VALUES (?, ?, ?, ?, ?, ?)", data)
conn.commit()

# %% [markdown]
# ## Exercise 1: ORDER BY practice

# %%
# TODO: Order sales
# 1. Order all sales by amount DESC (highest first)
# 2. Get top 3 sales by amount
# 3. Order by region alphabetically, then by amount DESC

# Your code here

# %% [markdown]
# ## Exercise 2: Aggregate functions

# %%
# TODO: Calculate aggregates
# 1. Total sales revenue
# 2. Average sale amount
# 3. Highest and lowest sale
# 4. Total number of sales

# Your code here

# %% [markdown]
# ## Exercise 3: GROUP BY analysis

# %%
# TODO: Group and aggregate
# 1. Total sales by salesperson
# 2. Total sales by region
# 3. Average sale by product
# 4. Count of sales by region

# Your code here

# %% [markdown]
# ## Exercise 4: HAVING and complex queries

# %%
# TODO: Filter groups and rank
# 1. Salespersons with total sales > 200
# 2. Regions with more than 2 sales
# 3. Products with average sale > 140, ordered by avg DESC
# 4. Top salesperson (most total revenue)

# Your code here
