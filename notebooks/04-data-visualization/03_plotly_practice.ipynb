# %% [markdown]
# # Visualizing Data with Plotly - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %%
import plotly.express as px
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercise 1: Interactive Line Chart with Multiple Datasets
#
# Create an interactive line chart showing stock prices for 3 companies over 12 months:
# - Company A: [100, 105, 110, 108, 115, 120, 125, 122, 130, 135, 140, 145]
# - Company B: [150, 148, 145, 152, 155, 158, 160, 158, 165, 168, 170, 175]
# - Company C: [50, 52, 55, 58, 56, 60, 62, 65, 68, 70, 72, 75]
#
# Requirements:
# 1. Create a single line chart with all 3 companies
# 2. Add markers on each data point
# 3. Include a legend
# 4. Add meaningful title and axis labels
# 5. Test the hover tooltip feature

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Interactive Scatter Plot with Color Coding
#
# Create an interactive scatter plot of student performance:
# - x-axis: Study Hours (10-50)
# - y-axis: Test Score (60-100)
# - Color: Grade Level (Freshman, Sophomore, Junior, Senior)
#
# Generate random data for 50 students.
#
# Requirements:
# 1. Use color to distinguish between grade levels
# 2. Add a meaningful title
# 3. Label axes clearly
# 4. Test the interactive features (hover, zoom, pan)

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Grouped Bar Chart for Category Comparison
#
# Create an interactive grouped bar chart comparing product sales across regions and quarters:
# - Regions: North, South, East, West
# - Quarters: Q1, Q2, Q3, Q4
# - Each region has sales data for each quarter
#
# Generate sample data.
#
# Requirements:
# 1. Use grouped bar chart format
# 2. Color bars by region
# 3. Add proper labels and title
# 4. Make it interactive and easy to compare

# %%
# Add your code here

# %% [markdown]
# ## Exercise 4: Stacked Bar Chart
#
# Create an interactive stacked bar chart showing budget allocation across departments:
# - Departments: Marketing, IT, HR, Operations, Sales
# - Budget categories: Salaries, Equipment, Training, Travel
#
# Generate sample data where each department has budget for all 4 categories.
#
# Requirements:
# 1. Use stacked bar chart (`barmode='stack'`)
# 2. Color each budget category differently
# 3. Include a legend
# 4. Add title and axis labels
# 5. Make it easy to see total and component values

# %%
# Add your code here
