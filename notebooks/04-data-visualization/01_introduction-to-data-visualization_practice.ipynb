# %% [markdown]
# # Introduction to Data Visualization - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %% [markdown]
# ## Exercise 1: Match Chart Types to Scenarios
#
# For each scenario below, identify the best chart type and explain why:
#
# 1. Showing website traffic (visits per day) over the last 3 months
# 2. Comparing sales revenue across 5 product categories
# 3. Showing the relationship between advertising spend and total revenue
# 4. Displaying the age distribution of customers in a store
# 5. Comparing quarterly performance for 3 different teams
# 6. Showing outliers in delivery times compared to the median

# %%
# Add your answers here (as text or comments)

# 1. Website traffic over 3 months:
# Chart type: ___________
# Why: 

# 2. Sales revenue across categories:
# Chart type: ___________
# Why: 

# 3. Advertising spend vs revenue:
# Chart type: ___________
# Why: 

# 4. Customer age distribution:
# Chart type: ___________
# Why: 

# 5. Quarterly performance comparison:
# Chart type: ___________
# Why: 

# 6. Delivery times with outliers:
# Chart type: ___________
# Why:

# %% [markdown]
# ## Exercise 2: Critique Existing Visualizations
#
# Consider this scenario: A company used a pie chart with 12 slices (one for each month's sales) to show monthly revenue trends.
#
# Answer the following:
# 1. What is wrong with this visualization choice?
# 2. What chart type would be better?
# 3. How could they improve the visualization to follow best practices?

# %%
# Add your analysis here

# %% [markdown]
# ## Exercise 3: Plan a Visualization
#
# You have a dataset of customer feedback scores (1-5 scale) for different aspects of service:
# - Cleanliness
# - Staff Friendliness
# - Speed of Service
# - Food Quality
# - Value for Money
#
# You want to communicate which areas are strengths and which need improvement.
#
# 1. What chart type would you use?
# 2. What would go on the x-axis and y-axis?
# 3. What title and labels would you include?
# 4. How would you use color to highlight insights?

# %%
# Add your visualization plan here
