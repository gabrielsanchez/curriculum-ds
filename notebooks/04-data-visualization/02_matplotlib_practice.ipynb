# %% [markdown]
# # Visualizing Data with Matplotlib - Practice
#
# Follow these simple steps to save your own copy of this notebook and begin working on it!
#
# ### **Save a Copy to Your Google Drive**
# 1. Click on **File** (top-left menu).
# 2. Select **"Save a copy in Drive"**.
# 3. This will create a copy of the notebook in your **Google Drive > Colab Notebooks** folder.
# 4. You can rename the file if needed by clicking on its title at the top.
#
# Now that you have your own copy, you can **edit, run code cells, and save your progress** without affecting the original notebook. If you make changes, they will be automatically saved to your Google Drive.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercise 1: Create a Line Chart with Multiple Series
#
# Create a line chart showing monthly temperature data for 3 cities:
# - New York: [32, 35, 47, 60, 71, 80, 85, 84, 77, 65, 50, 38]
# - Miami: [75, 76, 80, 84, 88, 90, 91, 90, 88, 85, 80, 76]
# - Seattle: [48, 49, 52, 56, 61, 66, 71, 71, 65, 54, 48, 46]
#
# Add:
# - Different markers for each city
# - A legend
# - Proper title and axis labels
# - Grid lines for readability

# %%
# Add your code here

# %% [markdown]
# ## Exercise 2: Create Bar Charts Comparing Categories
#
# Create a bar chart comparing quarterly revenue across 4 regions:
# - North: [150000, 160000, 175000, 190000]
# - South: [120000, 130000, 135000, 145000]
# - East: [180000, 185000, 195000, 210000]
# - West: [140000, 145000, 155000, 170000]
#
# Requirements:
# 1. Create a grouped bar chart (one bar per region for each quarter)
# 2. Add different colors for each region
# 3. Include a legend
# 4. Add title and axis labels
# 5. Format y-axis to show values in thousands (e.g., 150K)

# %%
# Add your code here

# %% [markdown]
# ## Exercise 3: Create Scatter Plot with Color Coding
#
# Create a scatter plot showing the relationship between:
# - x-axis: Hours Studied (10-50 hours)
# - y-axis: Test Score (60-100)
# - Color: Student Level (Beginner, Intermediate, Advanced)
#
# Use this sample data (or create your own):
# ```python
# study_hours = [10, 15, 20, 25, 30, 35, 40, 45, 50, 12, 18, 28, 38, 32, 22]
# test_scores = [62, 68, 72, 78, 85, 88, 92, 95, 98, 65, 70, 80, 90, 87, 75]
# levels = ['Beginner', 'Beginner', 'Intermediate', 'Intermediate', 'Advanced', ...]
# ```
#
# Requirements:
# 1. Plot points with different colors for each level
# 2. Add a legend showing the levels
# 3. Include clear title and axis labels
# 4. Add grid lines
# 5. Make the figure size at least 10x6

# %%
# Add your code here

# %% [markdown]
# ## Exercise 4: Create a Histogram with Multiple Distributions
#
# Create histograms showing the distribution of test scores for 3 different classes:
# - Class A: scores distributed around mean 75
# - Class B: scores distributed around mean 80
# - Class C: scores distributed around mean 70
#
# Generate sample data using `np.random.normal()` and display all 3 distributions on separate subplots.
#
# Requirements:
# 1. Create 3 subplots in a 1x3 layout
# 2. Each with different colors
# 3. Add appropriate titles for each
# 4. Use consistent binning and axis ranges
# 5. Add labels to axes

# %%
# Add your code here
